# %% [markdown]
# # Preprocessing Coaches Votes
#
# In this notebook we clean up the data that contains coaches votes from each game.
# This includes mapping the game and player to their respective match_id and player_id's so they can be joined
# onto a future dataframe with a primary key

# %%
import pandas as pd

# %%
data = pd.read_csv('../../data/landing/coaches_votes_12-22.csv')

# %%
data
# Out:
#          Unnamed: 0  Season  Round     Home.Team     Away.Team  \
# 0           1.1...1    2012      1    GWS Giants  Sydney Swans
# 1           1.2...2    2012      1    GWS Giants  Sydney Swans
# 2           1.3...3    2012      1    GWS Giants  Sydney Swans
# 3           1.4...4    2012      1    GWS Giants  Sydney Swans
# 4           1.5...5    2012      1    GWS Giants  Sydney Swans
# ...             ...     ...    ...           ...           ...
# 14456  32.2...14457    2022     27  Geelong Cats  Sydney Swans
# 14457  32.3...14458    2022     27  Geelong Cats  Sydney Swans
# 14458  32.4...14459    2022     27  Geelong Cats  Sydney Swans
# 14459  32.5...14460    2022     27  Geelong Cats  Sydney Swans
# 14460  32.6...14461    2022     27  Geelong Cats  Sydney Swans
#
#                       Player.Name  Coaches.Votes
# 0              Josh Kennedy (SYD)           10.0
# 1              Ted Richards (SYD)            7.0
# 2               Kieren Jack (SYD)            6.0
# 3                Craig Bird (SYD)            3.0
# 4               Chad Cornes (GWS)            2.0
# ...                           ...            ...
# 14456  Patrick Dangerfield (GEEL)           12.0
# 14457          Tom Hawkins (GEEL)            9.0
# 14458        Tyson Stengle (GEEL)            6.0
# 14459         Mark Blicavs (GEEL)            1.5
# 14460        Sam De Koning (GEEL)            1.5
#
# [14461 rows x 7 columns]

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# first things first, let's clean up those column names
for col in list(data.columns):
    
    col_out = col.replace('.','_').lower()
    
    print(f"'{col}': '{col_out}',")
# Out:
# 'Season': 'season',
# 'Round': 'round',
# 'Home.Team': 'home_team',
# 'Away.Team': 'away_team',
# 'Player.Name': 'player_name',
# 'Coaches.Votes': 'coaches_votes',

# %%
# add prefix "match_" for future df merges
data = data.rename(columns={
    'Season': 'season',
    'Round': 'match_round',
    'Home.Team': 'match_home_team',
    'Away.Team': 'match_away_team',
    'Player.Name': 'player_name',
    'Coaches.Votes': 'coaches_votes'
})

# %%
# also filter out finals games
match_round = [i for i in range(1, 24)]
data = data.query('match_round.isin(@match_round)')

# %%
# much nicer
data.head()
# Out:
#    season  match_round match_home_team match_away_team         player_name  \
# 0    2012            1      GWS Giants    Sydney Swans  Josh Kennedy (SYD)
# 1    2012            1      GWS Giants    Sydney Swans  Ted Richards (SYD)
# 2    2012            1      GWS Giants    Sydney Swans   Kieren Jack (SYD)
# 3    2012            1      GWS Giants    Sydney Swans    Craig Bird (SYD)
# 4    2012            1      GWS Giants    Sydney Swans   Chad Cornes (GWS)
#
#    coaches_votes
# 0           10.0
# 1            7.0
# 2            6.0
# 3            3.0
# 4            2.0

# %%
match_id = pd.read_parquet('../../data/raw/cleaned_stats_12-22_fixed_bv')

# %%
match_id = match_id[['match_id', 'match_home_team', 'match_away_team', 
                     'match_round', 'season', 'match_date', 
                     'player_id', 'player_first_name', 'player_last_name']]

# %%
match_id.head()
# Out:
#    match_id         match_home_team match_away_team  match_round  season  \
# 0     13960  Greater Western Sydney          Sydney            1    2012
# 1     13960  Greater Western Sydney          Sydney            1    2012
# 2     13960  Greater Western Sydney          Sydney            1    2012
# 3     13960  Greater Western Sydney          Sydney            1    2012
# 4     13960  Greater Western Sydney          Sydney            1    2012
#
#   match_date  player_id player_first_name player_last_name
# 0 2012-03-24      10822             James         McDonald
# 1 2012-03-24      10942              Adam           Goodes
# 2 2012-03-24      10973              Chad           Cornes
# 3 2012-03-24      10988              Jude           Bolton
# 4 2012-03-24      11183               Ted         Richards

# %%
old_teams = data.match_home_team.unique()
new_teams = match_id.match_home_team.unique()
# teams where name is different
list(set(old_teams) - set(new_teams))
# Out:
# ['West Coast Eagles',
#  'GWS Giants',
#  'Geelong Cats',
#  'Gold Coast Suns',
#  'Sydney Swans',
#  'Adelaide Crows']

# %%
list(set(new_teams) - set(old_teams))
# Out:
# ['Adelaide',
#  'Greater Western Sydney',
#  'Gold Coast',
#  'West Coast',
#  'Geelong',
#  'Sydney']

# %%
# extract player name from player_name column (i.e. without team)
data['player'] = data['player_name'].str.extract(r"(.*?) \(", expand=False)
# extract player team from player_name column
data['player_team'] = data['player_name'].str.extract(r"\((.*?)\)", expand=False)

# %%
data.player_team.unique()
# Out:
# array(['SYD', 'GWS', 'CARL', 'RICH', 'COLL', 'HAW', 'BL', 'MELB', 'ADEL',
#        'GCFC', 'FRE', 'GEEL', 'ESS', 'NMFC', 'WCE', 'WB', 'PORT', 'STK'],
#       dtype=object)

# %%
new_teams
# Out:
# <StringArray>
# ['Greater Western Sydney',               'Richmond',               'Hawthorn',
#               'Melbourne',             'Gold Coast',        'North Melbourne',
#               'Fremantle',       'Western Bulldogs',          'Port Adelaide',
#          'Brisbane Lions',               'Essendon',                 'Sydney',
#              'West Coast',               'Adelaide',            'Collingwood',
#                'St Kilda',                'Geelong',                'Carlton']
# Length: 18, dtype: string

# %%
team_dict = {
    # coaches_vote format: match_id format
    'GWS Giants':'Greater Western Sydney',
    'Sydney Swans':'Sydney',
    'West Coast Eagles':'West Coast',
    'Gold Coast Suns':'Gold Coast',
    'Geelong Cats':'Geelong',
    'Adelaide Crows':'Adelaide',
    
    # shortened team names: long team names
    'SYD': 'Sydney', 
    'GWS': 'Greater Western Sydney', 
    'CARL': 'Carlton', 
    'RICH': 'Richmond', 
    'COLL': 'Collingwood', 
    'HAW': 'Hawthorn', 
    'BL': 'Brisbane Lions', 
    'MELB': 'Melbourne', 
    'ADEL': 'Adelaide',    
    'GCFC': 'Gold Coast', 
    'FRE': 'Fremantle', 
    'GEEL': 'Geelong', 
    'ESS': 'Essendon', 
    'NMFC': 'North Melbourne', 
    'WCE': 'West Coast', 
    'WB': 'Western Bulldogs', 
    'PORT': 'Port Adelaide', 
    'STK': 'St Kilda'
}

# %%
data.replace({'match_home_team':team_dict, 'match_away_team':team_dict, 'player_team':team_dict}, inplace=True)

# %%
data.head()
# Out:
#    season  match_round         match_home_team match_away_team  \
# 0    2012            1  Greater Western Sydney          Sydney
# 1    2012            1  Greater Western Sydney          Sydney
# 2    2012            1  Greater Western Sydney          Sydney
# 3    2012            1  Greater Western Sydney          Sydney
# 4    2012            1  Greater Western Sydney          Sydney
#
#           player_name  coaches_votes        player             player_team
# 0  Josh Kennedy (SYD)           10.0  Josh Kennedy                  Sydney
# 1  Ted Richards (SYD)            7.0  Ted Richards                  Sydney
# 2   Kieren Jack (SYD)            6.0   Kieren Jack                  Sydney
# 3    Craig Bird (SYD)            3.0    Craig Bird                  Sydney
# 4   Chad Cornes (GWS)            2.0   Chad Cornes  Greater Western Sydney

# %%
match_id['player'] = match_id['player_first_name'] + ' ' + match_id['player_last_name']

# %%
match_id.head()
# Out:
#    match_id         match_home_team match_away_team  match_round  season  \
# 0     13960  Greater Western Sydney          Sydney            1    2012
# 1     13960  Greater Western Sydney          Sydney            1    2012
# 2     13960  Greater Western Sydney          Sydney            1    2012
# 3     13960  Greater Western Sydney          Sydney            1    2012
# 4     13960  Greater Western Sydney          Sydney            1    2012
#
#   match_date  player_id player_first_name player_last_name          player
# 0 2012-03-24      10822             James         McDonald  James McDonald
# 1 2012-03-24      10942              Adam           Goodes     Adam Goodes
# 2 2012-03-24      10973              Chad           Cornes     Chad Cornes
# 3 2012-03-24      10988              Jude           Bolton     Jude Bolton
# 4 2012-03-24      11183               Ted         Richards    Ted Richards

# %%
df = pd.merge(match_id, data, how='left', left_on=['match_home_team', 'match_away_team', 'match_round', 'season', 'player'],
                                    right_on=['match_home_team', 'match_away_team', 'match_round', 'season', 'player'])

# %%
df
# Out:
#        match_id         match_home_team match_away_team  match_round  season  \
# 0         13960  Greater Western Sydney          Sydney            1    2012
# 1         13960  Greater Western Sydney          Sydney            1    2012
# 2         13960  Greater Western Sydney          Sydney            1    2012
# 3         13960  Greater Western Sydney          Sydney            1    2012
# 4         13960  Greater Western Sydney          Sydney            1    2012
# ...         ...                     ...             ...          ...     ...
# 94111     16346                St Kilda          Sydney           23    2022
# 94112     16346                St Kilda          Sydney           23    2022
# 94113     16346                St Kilda          Sydney           23    2022
# 94114     16346                St Kilda          Sydney           23    2022
# 94115     16346                St Kilda          Sydney           23    2022
#
#       match_date  player_id player_first_name  player_last_name  \
# 0     2012-03-24      10822             James          McDonald
# 1     2012-03-24      10942              Adam            Goodes
# 2     2012-03-24      10973              Chad            Cornes
# 3     2012-03-24      10988              Jude            Bolton
# 4     2012-03-24      11183               Ted          Richards
# ...          ...        ...               ...               ...
# 94111 2022-08-21      12863             Logan          McDonald
# 94112 2022-08-21      12864             Errol            Gulden
# 94113 2022-08-21      12945             Mitch             Owens
# 94114 2022-08-21      12947            Nasiah  Wanganeen-Milera
# 94115 2022-08-21      12968            Marcus         Windhager
#
#                         player         player_name  coaches_votes  \
# 0               James McDonald                 NaN            NaN
# 1                  Adam Goodes                 NaN            NaN
# 2                  Chad Cornes   Chad Cornes (GWS)            2.0
# 3                  Jude Bolton                 NaN            NaN
# 4                 Ted Richards  Ted Richards (SYD)            7.0
# ...                        ...                 ...            ...
# 94111           Logan McDonald                 NaN            NaN
# 94112             Errol Gulden                 NaN            NaN
# 94113              Mitch Owens                 NaN            NaN
# 94114  Nasiah Wanganeen-Milera                 NaN            NaN
# 94115         Marcus Windhager                 NaN            NaN
#
#                   player_team
# 0                         NaN
# 1                         NaN
# 2      Greater Western Sydney
# 3                         NaN
# 4                      Sydney
# ...                       ...
# 94111                     NaN
# 94112                     NaN
# 94113                     NaN
# 94114                     NaN
# 94115                     NaN
#
# [94116 rows x 13 columns]

# %%
cols_keep = ['match_id', 'player_id', 'coaches_votes']
final_df = df[cols_keep].fillna(0)

# %%
final_df
# Out:
#        match_id  player_id  coaches_votes
# 0         13960      10822            0.0
# 1         13960      10942            0.0
# 2         13960      10973            2.0
# 3         13960      10988            0.0
# 4         13960      11183            7.0
# ...         ...        ...            ...
# 94111     16346      12863            0.0
# 94112     16346      12864            0.0
# 94113     16346      12945            0.0
# 94114     16346      12947            0.0
# 94115     16346      12968            0.0
#
# [94116 rows x 3 columns]

# %%
final_df.to_parquet('../../data/raw/coaches_votes.parquet')
