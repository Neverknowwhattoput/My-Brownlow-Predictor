# %% [markdown]
# ## Preprocessing Footytables Data
#
# In this notebook we preprocess the data collected from footy tables as it contains the brownlow votes from 2022.
#
# The aim is to derive the columns of interest and merge it with our original dataframe so that we have the brownlow votes information for all seasons.
#
# Unfortunately there is no nice key to merge the dataframes on and when merging via the first and last name of players, some the result was not as expected. This was because of the represenation of some names that included, two words like "De Goey" or "De Koning", names with apostrophes like "O'hallaron" and names with an initial like "Josh P. Kennedy". There is also the case where names such as "Thomas" were shortened to "Tom"
#
# So the names had to transformed to the same format so that they could be merged as intended.

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/landing/player_stats_22_tables.csv')
full_df = pd.read_parquet('../../data/raw/cleaned_stats_12-22.parquet')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Season', 'Round', 'Date', 'Local.start.time', 'Venue',
#        'Attendance', 'Home.team', 'HQ1G', 'HQ1B', 'HQ2G', 'HQ2B', 'HQ3G',
#        'HQ3B', 'HQ4G', 'HQ4B', 'Home.score', 'Away.team', 'AQ1G', 'AQ1B',
#        'AQ2G', 'AQ2B', 'AQ3G', 'AQ3B', 'AQ4G', 'AQ4B', 'Away.score',
#        'First.name', 'Surname', 'ID', 'Jumper.No.', 'Playing.for', 'Kicks',
#        'Marks', 'Handballs', 'Goals', 'Behinds', 'Hit.Outs', 'Tackles',
#        'Rebounds', 'Inside.50s', 'Clearances', 'Clangers', 'Frees.For',
#        'Frees.Against', 'Brownlow.Votes', 'Contested.Possessions',
#        'Uncontested.Possessions', 'Contested.Marks', 'Marks.Inside.50',
#        'One.Percenters', 'Bounces', 'Goal.Assists', 'Time.on.Ground..',
#        'Substitute', 'Umpire.1', 'Umpire.2', 'Umpire.3', 'Umpire.4',
#        'group_id'],
#       dtype='object')

# %%
df
# Out:
#       Unnamed: 0  Season Round        Date  Local.start.time   Venue  \
# 0              1    2022     1  2022-03-16              1910  M.C.G.
# 1              2    2022     1  2022-03-16              1910  M.C.G.
# 2              3    2022     1  2022-03-16              1910  M.C.G.
# 3              4    2022     1  2022-03-16              1910  M.C.G.
# 4              5    2022     1  2022-03-16              1910  M.C.G.
# ...          ...     ...   ...         ...               ...     ...
# 9517        9518    2022    GF  2022-09-24              1430  M.C.G.
# 9518        9519    2022    GF  2022-09-24              1430  M.C.G.
# 9519        9520    2022    GF  2022-09-24              1430  M.C.G.
# 9520        9521    2022    GF  2022-09-24              1430  M.C.G.
# 9521        9522    2022    GF  2022-09-24              1430  M.C.G.
#
#       Attendance  Home.team  HQ1G  HQ1B  ...  One.Percenters  Bounces  \
# 0          58002  Melbourne     4     5  ...               2        1
# 1          58002  Melbourne     4     5  ...               2        0
# 2          58002  Melbourne     4     5  ...               1        0
# 3          58002  Melbourne     4     5  ...               2        0
# 4          58002  Melbourne     4     5  ...               0        0
# ...          ...        ...   ...   ...  ...             ...      ...
# 9517      100024    Geelong     6     5  ...               6        1
# 9518      100024    Geelong     6     5  ...               1        0
# 9519      100024    Geelong     6     5  ...               4        0
# 9520      100024    Geelong     6     5  ...               0        3
# 9521      100024    Geelong     6     5  ...               0        3
#
#       Goal.Assists  Time.on.Ground..  Substitute        Umpire.1  \
# 0                0                55         NaN    John Howorth
# 1                0                73         NaN    John Howorth
# 2                0                83         NaN    John Howorth
# 3                0                86         NaN    John Howorth
# 4                1                81         NaN    John Howorth
# ...            ...               ...         ...             ...
# 9517             0                90         NaN  Simon Meredith
# 9518             0                38         NaN  Simon Meredith
# 9519             1                72         NaN  Simon Meredith
# 9520             1                78         NaN  Simon Meredith
# 9521             1                78         NaN  Simon Meredith
#
#           Umpire.2          Umpire.3  Umpire.4  group_id
# 0      Rob Findlay    Jacob Mollison       NaN       NaN
# 1      Rob Findlay    Jacob Mollison       NaN       NaN
# 2      Rob Findlay    Jacob Mollison       NaN       NaN
# 3      Rob Findlay    Jacob Mollison       NaN       NaN
# 4      Rob Findlay    Jacob Mollison       NaN       NaN
# ...            ...               ...       ...       ...
# 9517   Matt Stevic   Brendan Hosking       NaN       NaN
# 9518   Matt Stevic   Brendan Hosking       NaN       NaN
# 9519   Matt Stevic   Brendan Hosking       NaN       NaN
# 9520   Matt Stevic   Brendan Hosking       NaN       NaN
# 9521   Matt Stevic   Brendan Hosking       NaN       NaN
#
# [9522 rows x 60 columns]

# %%
rounds = [str(i) for i in range(1,24)]
df = df.query('Round.isin(@rounds)')

# %%
keep_col = [
    'Home.team', 'Away.team', 'Round', 'First.name', 'Surname', 'Playing.for', 'Brownlow.Votes'
]

# %%
df = df[keep_col]

# %%
for col in keep_col:
    print(f'"{col}": "{col.lower().replace(".","_")}",')
# Out:
# "Home.team": "home_team",
# "Away.team": "away_team",
# "Round": "round",
# "First.name": "first_name",
# "Surname": "surname",
# "Playing.for": "playing_for",
# "Brownlow.Votes": "brownlow_votes",

# %%
df.rename(columns={
    "Home.team": "home_team",
    "Away.team": "away_team",
    "Round": "round_number",
    "First.name": "first_name",
    "Surname": "surname",
    "Playing.for": "playing_for",
    "Brownlow.Votes": "brownlow_votes"
}, inplace=True)

# %%
df = df.astype({
    'round_number':'int'
})

# %%
df
# Out:
#       home_team         away_team  round_number first_name    surname  \
# 0     Melbourne  Western Bulldogs             1       Toby    Bedford
# 1     Melbourne  Western Bulldogs             1       Jake      Bowey
# 2     Melbourne  Western Bulldogs             1      Angus   Brayshaw
# 3     Melbourne  Western Bulldogs             1        Ben      Brown
# 4     Melbourne  Western Bulldogs             1     Bayley    Fritsch
# ...         ...               ...           ...        ...        ...
# 9103   St Kilda            Sydney            23        Sam       Reid
# 9104   St Kilda            Sydney            23      James  Rowbottom
# 9105   St Kilda            Sydney            23      Dylan   Stephens
# 9106   St Kilda            Sydney            23       Chad     Warner
# 9107   St Kilda            Sydney            23        Sam      Wicks
#
#      playing_for  brownlow_votes
# 0      Melbourne               0
# 1      Melbourne               0
# 2      Melbourne               0
# 3      Melbourne               0
# 4      Melbourne               0
# ...          ...             ...
# 9103      Sydney               0
# 9104      Sydney               0
# 9105      Sydney               0
# 9106      Sydney               0
# 9107      Sydney               0
#
# [9108 rows x 7 columns]

# %%
# realistically we only need to merge rows where a player polled, and all remaining will be na
# which can be filled with .fillna(0)
polled = df.query('brownlow_votes > 0')

# %%
polled.head()
# Out:
#     home_team         away_team  round_number first_name   surname  \
# 14  Melbourne  Western Bulldogs             1    Clayton    Oliver
# 15  Melbourne  Western Bulldogs             1  Christian  Petracca
# 35  Melbourne  Western Bulldogs             1       Jack    Macrae
# 46    Carlton          Richmond             1       Adam     Cerra
# 47    Carlton          Richmond             1    Patrick    Cripps
#
#          playing_for  brownlow_votes
# 14         Melbourne               1
# 15         Melbourne               3
# 35  Western Bulldogs               2
# 46           Carlton               3
# 47           Carlton               1

# %%
# 3 players * 9 games * 22 rounds (exclude bye round)
len(polled)
# Out:
# 594

# %%
df_2022 = full_df.loc[full_df['season'] == 2022]

# %%
df_2022
# Out:
#        match_id match_home_team   match_away_team match_date  match_round  \
# 85008     16117       Melbourne  Western Bulldogs 2022-03-16            1
# 85009     16117       Melbourne  Western Bulldogs 2022-03-16            1
# 85010     16117       Melbourne  Western Bulldogs 2022-03-16            1
# 85011     16117       Melbourne  Western Bulldogs 2022-03-16            1
# 85012     16117       Melbourne  Western Bulldogs 2022-03-16            1
# ...         ...             ...               ...        ...          ...
# 94111     16346        St Kilda            Sydney 2022-08-21           23
# 94112     16346        St Kilda            Sydney 2022-08-21           23
# 94113     16346        St Kilda            Sydney 2022-08-21           23
# 94114     16346        St Kilda            Sydney 2022-08-21           23
# 94115     16346        St Kilda            Sydney 2022-08-21           23
#
#        season  match_home_team_goals  match_home_team_behinds  \
# 85008    2022                     14                       13
# 85009    2022                     14                       13
# 85010    2022                     14                       13
# 85011    2022                     14                       13
# 85012    2022                     14                       13
# ...       ...                    ...                      ...
# 94111    2022                     11                        8
# 94112    2022                     11                        8
# 94113    2022                     11                        8
# 94114    2022                     11                        8
# 94115    2022                     11                        8
#
#        match_home_team_score  match_away_team_goals  ...  \
# 85008                     97                     11  ...
# 85009                     97                     11  ...
# 85010                     97                     11  ...
# 85011                     97                     11  ...
# 85012                     97                     11  ...
# ...                      ...                    ...  ...
# 94111                     74                     13  ...
# 94112                     74                     13  ...
# 94113                     74                     13  ...
# 94114                     74                     13  ...
# 94115                     74                     13  ...
#
#        hitouts_to_advantage  hitout_win_percentage  intercept_marks  \
# 85008                     0                      0                0
# 85009                     0                      0                3
# 85010                     8                     64                1
# 85011                     0                      0                1
# 85012                     0                      0                1
# ...                     ...                    ...              ...
# 94111                     0                      0                0
# 94112                     0                      0                1
# 94113                     0                      0                0
# 94114                     0                      0                0
# 94115                     0                      0                0
#
#       marks_on_lead  pressure_acts rating_points ruck_contests score_launches  \
# 85008             1             23             4             0              0
# 85009             0              3             9             0              1
# 85010             0             15            10            53              5
# 85011             0             16             6             0              1
# 85012             0              4             2             0              0
# ...             ...            ...           ...           ...            ...
# 94111             1              8             5             0              1
# 94112             0             21             6             0              1
# 94113             0             23             5             0              0
# 94114             3             13             2             0              2
# 94115             0             13             5             0              0
#
#       shots_at_goal  spoils
# 85008             0       0
# 85009             0      10
# 85010             2       3
# 85011             1       4
# 85012             0       3
# ...             ...     ...
# 94111             3       0
# 94112             1       0
# 94113             2       1
# 94114             2       0
# 94115             1       0
#
# [9108 rows x 70 columns]

# %%
cols_2022 = ['match_round', 'player_first_name', 'player_last_name', 'player_team']

# %%
# we get 8531 rows when we expected 8514 (9108 - 594)
# therefore there are 17 cases where the player's names are represented differently

new_df = pd.merge(df_2022, polled, 
         left_on=['player_first_name', 'player_last_name', 'match_round'], 
         right_on=['first_name', 'surname', 'round_number'],
        how='left')

# we get 8531 rows when we expected 8514 (9108 - 594)
# therefore there are 17 cases where the player's names are represented differently

len(new_df[new_df.isna().any(axis=1)])
# Out:
# 8531

# %%
interim_df = pd.merge(df_2022, df, 
         left_on=['player_first_name', 'player_last_name', 'match_round'], 
         right_on=['first_name', 'surname', 'round_number'],
        how='left')
len(interim_df[interim_df.isna().any(axis=1)])
# Out:
# 346

# %%
# list of last names where there is a naming difference
interim_df[interim_df.isna().any(axis=1)][cols_2022].player_last_name.unique()
# Out:
# array(['Williamson', "O'Brien", 'De Goey', 'Kennedy', 'de Boer',
#        'Himmelberg', "O'Riordan", "O'Halloran", "O'Meara", 'Hinge',
#        'Macpherson', 'Rioli', "O'Neill", 'Williams', 'Dewar',
#        "O'Driscoll", 'Ryder', 'Taberner', "O'Connor", 'Brown', 'Petty',
#        'Berry', 'Jones', "D'Ambrosio", 'Oea'], dtype=object)

# %%
# list of last names where there is a naming difference
polled.surname.unique()
# Out:
# array(['Oliver', 'Petracca', 'Macrae', 'Cerra', 'Cripps', 'Kennedy',
#        'Hayes', 'de Goey', 'Lipinski', 'Dangerfield', 'Hawkins', 'Martin',
#        'Green', 'Heeney', 'Parker', 'Neale', 'Boak', 'Houston', 'Jiath',
#        'Mitchell', 'McDonald', 'Keays', 'Rachele', 'Brayshaw', 'Miller',
#        'Rankine', 'Rowell', 'Curnow', 'McKay', 'Franklin', 'Mills',
#        'Crisp', 'Merrett', 'McCluggage', 'Lewis', 'Greenwood', 'Larkey',
#        'Ziebell', 'Balta', 'Short', 'Taranto', 'Higgins', 'King',
#        'Dunkley', 'English', 'Smith', 'Langdon', 'Dawson', 'Marshall',
#        'Kelly', 'Elliott', 'Cameron', 'Stewart', 'Lyons', 'McCarthy',
#        'Zorko', 'Docherty', 'Hewett', 'Gresham', 'Steele', 'Brodie',
#        'Schultz', 'Gawn', 'Harmes', 'McStay', 'McInerney', 'Simpkin',
#        'Daicos', 'Grundy', 'McGovern', 'Mundy', 'Bolton', 'Prestia',
#        'Parish', 'Walker', 'Hill', 'Sinclair', 'Anderson', 'Weller',
#        'Williams', 'Bontempelli', 'Naughton', 'Ladhams', 'Walsh', 'Darcy',
#        'Taberner', 'Newcombe', 'Sicily', 'Crouch', 'OBrien', 'Rozee',
#        'Wines', 'Lobb', 'Pearce', 'Guthrie', 'Tuohy', 'Bailey',
#        'Ginnivan', 'Lynch', 'Blicavs', 'Acres', 'Cumming', 'Hogan',
#        'Ross', 'Graham', 'Fiorini', 'Swallow', 'Witts', 'Stengle',
#        'Wright', 'Treloar', 'Amon', 'Powell-Pepper', 'Ryder', 'Papley',
#        'Warner', 'Chol', 'Pickett', 'Scott', 'Baker', 'Riewoldt',
#        'Coniglio', 'Peatling', 'Henry', 'Cotchin', 'Laird', 'Berry',
#        'Ellis', 'Liberatore', 'Duncan', 'Gaff', 'Budarick', 'Reid',
#        'Serong', 'Newman', 'Young', 'OMeara', 'Bruhn', 'Himmelberg',
#        'Cox', 'Mihocek', 'Redman', 'Shiel', 'Menegola', 'Greene',
#        'Ainsworth', 'Jackson', 'Lever', 'Viney', 'Rioli', 'Lloyd',
#        'McCartin', 'Fogarty', 'Sidebottom', 'Membrey', 'Hind', 'Broad',
#        'Brown', 'Aish', 'Davies-Uniacke', 'Clark', 'Dixon', 'Ridley',
#        'Pendlebury', 'Mathieson', 'Rayner', 'Zurhaar', 'Selwood',
#        'Gulden', 'Breust', 'Moore', 'Gunston', 'Ugle-Hagan', 'Saad',
#        'Adams', 'Draper', 'Butler', 'Darling', 'Coleman', 'Stringer',
#        'Ward', 'Whitfield', 'Ryan', 'Holmes', 'Nankervis', 'Wood', 'Dale',
#        'Melksham', 'Butters', 'Finlayson', 'Taylor', 'Sexton',
#        'Hannebery', 'Long'], dtype=object)

# %%
# browsing both lists, these are the intersection

fix = [
    'Obrien', 'de Goey',  'Kennedy', 'Himmelberg', 'Omeara',  'rioli', 'Williams', 
    'ryder', 'taberner', 'brown', 'berry', 
]

# %% [markdown]
# We query each dataframe with the incorrect names, and overwrite the polled dataframe to match the 2022 dataframe.
#
# Not ideal that the indexes are hardcoded, but due to the nature of the problem, each is unique and fairly specific since they are names that are being changed.

# %%
polled.query('surname == "Kennedy"')
# Out:
#        home_team away_team  round_number first_name  surname playing_for  \
# 54       Carlton  Richmond             1    Matthew  Kennedy     Carlton
# 5485  West Coast  Essendon            15       Josh  Kennedy  West Coast
# 6612  West Coast   Carlton            17    Matthew  Kennedy     Carlton
# 8246  West Coast  Adelaide            21       Josh  Kennedy  West Coast
#
#       brownlow_votes
# 54                 2
# 5485               3
# 6612               2
# 8246               3

# %%
df_2022.query('player_last_name == "Kennedy"')[cols_2022][:5]
# Out:
#        match_round player_first_name player_last_name player_team
# 85077            1           Matthew          Kennedy     Carlton
# 85193            1           Josh P.          Kennedy      Sydney
# 85377            1           Josh J.          Kennedy  West Coast
# 85492            2           Matthew          Kennedy     Carlton
# 85517            2           Josh P.          Kennedy      Sydney

# %%
polled.loc[2157, 'surname'] = "O'Brien"

# %%
polled.loc[[122, 512, 1686, 2467, 7506], 'surname'] = "De Goey"

# %%
polled.loc[[5485, 8246], 'first_name'] = 'Josh J.'

# %%
polled.loc[[5045, 5736], 'first_name'] = "Harry"

# %%
polled.loc[[4962, 7930], 'surname'] = "O'Meara"

# %%
polled.loc[5488, 'first_name'] = 'Junior'

# %%
# no fix for williams, name difference was for Bailey J. Williams, but player that polled was Zac Williams

# %%
polled.loc[[3465, 5880], 'first_name'] = 'Paddy'

# %%
polled.loc[2019, 'first_name'] = 'Matt'

# %%
polled.loc[6119, 'first_name'] = 'Callum M.'

# %%
# Sam and Jarrod polled, Thomas Berry shows as n/a, but will be set to zero

# %%
new_df = pd.merge(df_2022, polled, 
         left_on=['player_first_name', 'player_last_name', 'match_round'], 
         right_on=['first_name', 'surname', 'round_number'],
        how='left')

# successfully fixed all 17 incorrect cases

len(new_df[new_df.isna().any(axis=1)])
# Out:
# 8514

# %%
# this tells us we wish to keep the y column
new_df[['player_first_name', 'player_last_name', 
        'match_id', 'brownlow_votes_x', 'brownlow_votes_y']].sort_values('brownlow_votes_y')
# Out:
#      player_first_name  player_last_name  match_id  brownlow_votes_x  \
# 9078              Jack            Steele     16346                 0
# 2082              Josh             Kelly     16168                 0
# 6968         Christian          Petracca     16293                 0
# 3785             Ollie             Wines     16211                 0
# 2144            Bailey             Smith     16169                 0
# ...                ...               ...       ...               ...
# 9103             Logan          McDonald     16346                 0
# 9104             Errol            Gulden     16346                 0
# 9105             Mitch             Owens     16346                 0
# 9106            Nasiah  Wanganeen-Milera     16346                 0
# 9107            Marcus         Windhager     16346                 0
#
#       brownlow_votes_y
# 9078               1.0
# 2082               1.0
# 6968               1.0
# 3785               1.0
# 2144               1.0
# ...                ...
# 9103               NaN
# 9104               NaN
# 9105               NaN
# 9106               NaN
# 9107               NaN
#
# [9108 rows x 5 columns]

# %%
# set all columns where brownlow votes is na to null
new_df.loc[new_df['brownlow_votes_y'].isna(), 'brownlow_votes_y'] = 0

# %%
new_df.rename(columns={'brownlow_votes_y': 'brownlow_votes'}, inplace=True)

# %%
new_df
# Out:
#       match_id match_home_team   match_away_team match_date  match_round  \
# 0        16117       Melbourne  Western Bulldogs 2022-03-16            1
# 1        16117       Melbourne  Western Bulldogs 2022-03-16            1
# 2        16117       Melbourne  Western Bulldogs 2022-03-16            1
# 3        16117       Melbourne  Western Bulldogs 2022-03-16            1
# 4        16117       Melbourne  Western Bulldogs 2022-03-16            1
# ...        ...             ...               ...        ...          ...
# 9103     16346        St Kilda            Sydney 2022-08-21           23
# 9104     16346        St Kilda            Sydney 2022-08-21           23
# 9105     16346        St Kilda            Sydney 2022-08-21           23
# 9106     16346        St Kilda            Sydney 2022-08-21           23
# 9107     16346        St Kilda            Sydney 2022-08-21           23
#
#       season  match_home_team_goals  match_home_team_behinds  \
# 0       2022                     14                       13
# 1       2022                     14                       13
# 2       2022                     14                       13
# 3       2022                     14                       13
# 4       2022                     14                       13
# ...      ...                    ...                      ...
# 9103    2022                     11                        8
# 9104    2022                     11                        8
# 9105    2022                     11                        8
# 9106    2022                     11                        8
# 9107    2022                     11                        8
#
#       match_home_team_score  match_away_team_goals  ...  score_launches  \
# 0                        97                     11  ...               0
# 1                        97                     11  ...               1
# 2                        97                     11  ...               5
# 3                        97                     11  ...               1
# 4                        97                     11  ...               0
# ...                     ...                    ...  ...             ...
# 9103                     74                     13  ...               1
# 9104                     74                     13  ...               1
# 9105                     74                     13  ...               0
# 9106                     74                     13  ...               2
# 9107                     74                     13  ...               0
#
#       shots_at_goal  spoils home_team  away_team round_number first_name  \
# 0                 0       0       NaN        NaN          NaN        NaN
# 1                 0      10       NaN        NaN          NaN        NaN
# 2                 2       3       NaN        NaN          NaN        NaN
# 3                 1       4       NaN        NaN          NaN        NaN
# 4                 0       3       NaN        NaN          NaN        NaN
# ...             ...     ...       ...        ...          ...        ...
# 9103              3       0       NaN        NaN          NaN        NaN
# 9104              1       0       NaN        NaN          NaN        NaN
# 9105              2       1       NaN        NaN          NaN        NaN
# 9106              2       0       NaN        NaN          NaN        NaN
# 9107              1       0       NaN        NaN          NaN        NaN
#
#      surname playing_for  brownlow_votes
# 0        NaN         NaN             0.0
# 1        NaN         NaN             0.0
# 2        NaN         NaN             0.0
# 3        NaN         NaN             0.0
# 4        NaN         NaN             0.0
# ...      ...         ...             ...
# 9103     NaN         NaN             0.0
# 9104     NaN         NaN             0.0
# 9105     NaN         NaN             0.0
# 9106     NaN         NaN             0.0
# 9107     NaN         NaN             0.0
#
# [9108 rows x 77 columns]

# %%
final_df_col = list(full_df.columns)

# %%
new_df = new_df[final_df_col]

# %%
# will be used with 2023 data to get past polling perforamnce
new_df.to_parquet('../../data/curated/brownlow_votes_22.parquet')

# %%
full_df = full_df.query('season < 2022')
full_df
# Out:
#        match_id         match_home_team  match_away_team match_date  \
# 0         13960  Greater Western Sydney           Sydney 2012-03-24
# 1         13960  Greater Western Sydney           Sydney 2012-03-24
# 2         13960  Greater Western Sydney           Sydney 2012-03-24
# 3         13960  Greater Western Sydney           Sydney 2012-03-24
# 4         13960  Greater Western Sydney           Sydney 2012-03-24
# ...         ...                     ...              ...        ...
# 85003     16105                Adelaide  North Melbourne 2021-08-22
# 85004     16105                Adelaide  North Melbourne 2021-08-22
# 85005     16105                Adelaide  North Melbourne 2021-08-22
# 85006     16105                Adelaide  North Melbourne 2021-08-22
# 85007     16105                Adelaide  North Melbourne 2021-08-22
#
#        match_round  season  match_home_team_goals  match_home_team_behinds  \
# 0                1    2012                      5                        7
# 1                1    2012                      5                        7
# 2                1    2012                      5                        7
# 3                1    2012                      5                        7
# 4                1    2012                      5                        7
# ...            ...     ...                    ...                      ...
# 85003           23    2021                     13                       20
# 85004           23    2021                     13                       20
# 85005           23    2021                     13                       20
# 85006           23    2021                     13                       20
# 85007           23    2021                     13                       20
#
#        match_home_team_score  match_away_team_goals  ...  \
# 0                         37                     14  ...
# 1                         37                     14  ...
# 2                         37                     14  ...
# 3                         37                     14  ...
# 4                         37                     14  ...
# ...                      ...                    ...  ...
# 85003                     98                      8  ...
# 85004                     98                      8  ...
# 85005                     98                      8  ...
# 85006                     98                      8  ...
# 85007                     98                      8  ...
#
#        hitouts_to_advantage  hitout_win_percentage  intercept_marks  \
# 0                         0                      0                0
# 1                         1                      0                0
# 2                         0                      0                3
# 3                         0                      0                1
# 4                         0                      0                8
# ...                     ...                    ...              ...
# 85003                     1                     16                0
# 85004                     0                      0                0
# 85005                     0                      0                0
# 85006                     0                      0                0
# 85007                     0                      0                0
#
#       marks_on_lead  pressure_acts rating_points ruck_contests score_launches  \
# 0                 1             15            11             0              2
# 1                 2             12             9             0              1
# 2                 0             15            12             0              1
# 3                 0             23            15             0              2
# 4                 0              7            16             0              2
# ...             ...            ...           ...           ...            ...
# 85003             0              8             6            18              2
# 85004             1             15             3             0              0
# 85005             0              6             9             0              2
# 85006             0              9             4             0              0
# 85007             0             10            -3             0              0
#
#       shots_at_goal  spoils
# 0                 1       1
# 1                 2       1
# 2                 0       3
# 3                 1       0
# 4                 0       3
# ...             ...     ...
# 85003             3       1
# 85004             1       0
# 85005             0       0
# 85006             3       0
# 85007             1       1
#
# [85008 rows x 70 columns]

# %%
final_df = pd.concat([full_df, new_df])

# %%
final_df.to_parquet('../../data/raw/cleaned_stats_12-22_fixed_bv.parquet')
