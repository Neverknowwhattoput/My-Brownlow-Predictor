# %% [markdown]
# ## Preprocessing Footytables Data
#
# In this notebook we preprocess the data collected from footy tables as it contains the brownlow votes from 2022.
#
# The aim is to derive the columns of interest and merge it with our original dataframe so that we have the brownlow votes information for all seasons.
#
# Unfortunately there is no nice key to merge the dataframes on and when merging via the first and last name of players, some the result was not as expected. This was because of the represenation of some names that included, two words like "De Goey" or "De Koning", names with apostrophes like "O'hallaron" and names with an initial like "Josh P. Kennedy". There is also the case where names such as "Thomas" were shortened to "Tom"
#
# So the names had to transformed to the same format so that they could be merged as intended.

# %%
import pandas as pd

# %%
# load afl_tables dataset
df = pd.read_csv('../../data/landing/player_stats_22_tables.csv', index_col=0)

# %%
df.columns
# Out:
# Index(['Season', 'Round', 'Date', 'Local.start.time', 'Venue', 'Attendance',
#        'Home.team', 'HQ1G', 'HQ1B', 'HQ2G', 'HQ2B', 'HQ3G', 'HQ3B', 'HQ4G',
#        'HQ4B', 'Home.score', 'Away.team', 'AQ1G', 'AQ1B', 'AQ2G', 'AQ2B',
#        'AQ3G', 'AQ3B', 'AQ4G', 'AQ4B', 'Away.score', 'First.name', 'Surname',
#        'ID', 'Jumper.No.', 'Playing.for', 'Kicks', 'Marks', 'Handballs',
#        'Goals', 'Behinds', 'Hit.Outs', 'Tackles', 'Rebounds', 'Inside.50s',
#        'Clearances', 'Clangers', 'Frees.For', 'Frees.Against',
#        'Brownlow.Votes', 'Contested.Possessions', 'Uncontested.Possessions',
#        'Contested.Marks', 'Marks.Inside.50', 'One.Percenters', 'Bounces',
#        'Goal.Assists', 'Time.on.Ground..', 'Substitute', 'Umpire.1',
#        'Umpire.2', 'Umpire.3', 'Umpire.4', 'group_id'],
#       dtype='object')

# %%
df
# Out:
#       Season Round        Date  Local.start.time   Venue  Attendance  \
# 1       2022     1  2022-03-16              1910  M.C.G.       58002
# 2       2022     1  2022-03-16              1910  M.C.G.       58002
# 3       2022     1  2022-03-16              1910  M.C.G.       58002
# 4       2022     1  2022-03-16              1910  M.C.G.       58002
# 5       2022     1  2022-03-16              1910  M.C.G.       58002
# ...      ...   ...         ...               ...     ...         ...
# 9518    2022    GF  2022-09-24              1430  M.C.G.      100024
# 9519    2022    GF  2022-09-24              1430  M.C.G.      100024
# 9520    2022    GF  2022-09-24              1430  M.C.G.      100024
# 9521    2022    GF  2022-09-24              1430  M.C.G.      100024
# 9522    2022    GF  2022-09-24              1430  M.C.G.      100024
#
#       Home.team  HQ1G  HQ1B  HQ2G  ...  One.Percenters  Bounces  Goal.Assists  \
# 1     Melbourne     4     5     6  ...               2        1             0
# 2     Melbourne     4     5     6  ...               2        0             0
# 3     Melbourne     4     5     6  ...               1        0             0
# 4     Melbourne     4     5     6  ...               2        0             0
# 5     Melbourne     4     5     6  ...               0        0             1
# ...         ...   ...   ...   ...  ...             ...      ...           ...
# 9518    Geelong     6     5     9  ...               6        1             0
# 9519    Geelong     6     5     9  ...               1        0             0
# 9520    Geelong     6     5     9  ...               4        0             1
# 9521    Geelong     6     5     9  ...               0        3             1
# 9522    Geelong     6     5     9  ...               0        3             1
#
#       Time.on.Ground..  Substitute        Umpire.1      Umpire.2  \
# 1                   55         NaN    John Howorth   Rob Findlay
# 2                   73         NaN    John Howorth   Rob Findlay
# 3                   83         NaN    John Howorth   Rob Findlay
# 4                   86         NaN    John Howorth   Rob Findlay
# 5                   81         NaN    John Howorth   Rob Findlay
# ...                ...         ...             ...           ...
# 9518                90         NaN  Simon Meredith   Matt Stevic
# 9519                38         NaN  Simon Meredith   Matt Stevic
# 9520                72         NaN  Simon Meredith   Matt Stevic
# 9521                78         NaN  Simon Meredith   Matt Stevic
# 9522                78         NaN  Simon Meredith   Matt Stevic
#
#               Umpire.3  Umpire.4  group_id
# 1       Jacob Mollison       NaN       NaN
# 2       Jacob Mollison       NaN       NaN
# 3       Jacob Mollison       NaN       NaN
# 4       Jacob Mollison       NaN       NaN
# 5       Jacob Mollison       NaN       NaN
# ...                ...       ...       ...
# 9518   Brendan Hosking       NaN       NaN
# 9519   Brendan Hosking       NaN       NaN
# 9520   Brendan Hosking       NaN       NaN
# 9521   Brendan Hosking       NaN       NaN
# 9522   Brendan Hosking       NaN       NaN
#
# [9522 rows x 59 columns]

# %%
rounds = [str(i) for i in range(1,24)]
df = df.query('Round.isin(@rounds)')

# %%
keep_col = [
    'Home.team', 'Away.team', 'Round', 'First.name', 'Surname', 'Playing.for', 'Brownlow.Votes'
]

# %%
df = df[keep_col]

# %%
for col in keep_col:
    print(f'"{col}": "{col.lower().replace(".","_")}",')
# Out:
# "Home.team": "home_team",
# "Away.team": "away_team",
# "Round": "round",
# "First.name": "first_name",
# "Surname": "surname",
# "Playing.for": "playing_for",
# "Brownlow.Votes": "brownlow_votes",

# %%
df.rename(columns={
    "Home.team": "home_team",
    "Away.team": "away_team",
    "Round": "round_number",
    "First.name": "first_name",
    "Surname": "surname",
    "Playing.for": "player_team",
    "Brownlow.Votes": "brownlow_votes"
}, inplace=True)

# %%
df = df.astype({
    'round_number':'int'
})

# %%
df
# Out:
#       home_team         away_team  round_number first_name    surname  \
# 1     Melbourne  Western Bulldogs             1       Toby    Bedford
# 2     Melbourne  Western Bulldogs             1       Jake      Bowey
# 3     Melbourne  Western Bulldogs             1      Angus   Brayshaw
# 4     Melbourne  Western Bulldogs             1        Ben      Brown
# 5     Melbourne  Western Bulldogs             1     Bayley    Fritsch
# ...         ...               ...           ...        ...        ...
# 9104   St Kilda            Sydney            23        Sam       Reid
# 9105   St Kilda            Sydney            23      James  Rowbottom
# 9106   St Kilda            Sydney            23      Dylan   Stephens
# 9107   St Kilda            Sydney            23       Chad     Warner
# 9108   St Kilda            Sydney            23        Sam      Wicks
#
#      player_team  brownlow_votes
# 1      Melbourne               0
# 2      Melbourne               0
# 3      Melbourne               0
# 4      Melbourne               0
# 5      Melbourne               0
# ...          ...             ...
# 9104      Sydney               0
# 9105      Sydney               0
# 9106      Sydney               0
# 9107      Sydney               0
# 9108      Sydney               0
#
# [9108 rows x 7 columns]

# %%
# realistically we only need to merge rows where a player polled, and all remaining will be na
# which can be filled with .fillna(0)
polled = df.query('brownlow_votes > 0')

# %%
polled.head()
# Out:
#     home_team         away_team  round_number first_name   surname  \
# 15  Melbourne  Western Bulldogs             1    Clayton    Oliver
# 16  Melbourne  Western Bulldogs             1  Christian  Petracca
# 36  Melbourne  Western Bulldogs             1       Jack    Macrae
# 47    Carlton          Richmond             1       Adam     Cerra
# 48    Carlton          Richmond             1    Patrick    Cripps
#
#          player_team  brownlow_votes
# 15         Melbourne               1
# 16         Melbourne               3
# 36  Western Bulldogs               2
# 47           Carlton               3
# 48           Carlton               1

# %%
# 3 players * 9 games * 22 rounds (exclude bye round)
len(polled)
# Out:
# 594

# %%
players = pd.read_parquet('../../data/curated/player_information_12-22.parquet').query('season == 2022')

# %%
players
# Out:
#        season  player_id       player_team  no_teams player_first_name  \
# 85008    2022      11904  Western Bulldogs         1               Tom
# 85009    2022      11945         Melbourne         2            Steven
# 85010    2022      11972         Melbourne         1               Max
# 85011    2022      12015         Melbourne         1               Tom
# 85012    2022      12034         Melbourne         2              Adam
# ...       ...        ...               ...       ...               ...
# 93832    2022      12939   North Melbourne         1           Charlie
# 93839    2022      13024   North Melbourne         1              Josh
# 93889    2022      11731          Essendon         1           Michael
# 94022    2022      13025          Hawthorn         1               Ned
# 94023    2022      13026          Hawthorn         1              Jack
#
#       player_last_name  process_name
# 85008       Liberatore  t liberatore
# 85009              May         s may
# 85010             Gawn        m gawn
# 85011         McDonald    t mcdonald
# 85012        Tomlinson   a tomlinson
# ...                ...           ...
# 93832           Comben      c comben
# 93839           Goater      j goater
# 93889           Hurley      m hurley
# 94022             Long        n long
# 94023         Saunders    j saunders
#
# [683 rows x 7 columns]

# %%
# process_name and player_team together is a unique identifier
len(players.drop_duplicates(['process_name', 'player_team']))
# Out:
# 683

# %%
def transform_name(row):
    
    """
    function to transform player name such that we take the first name initial and last name
    in the case of the 4 players where this is not unique (when paired with player team) we take the full first name
    puncuation is removed from player's names as well

    e.g. 
    1. Sam De Koning => s de koning
    2. Jaeger O'Meara => j omeara
    3. Jeremy Cameron => j cameron
    """

    first = row['first_name']
    lst = row['surname'].replace("'", "").split('-')


    if '-' in row['surname']:
        return_name = f'{first[0]} {lst[0][0]}-{lst[1]}'
        return return_name.lower()
    
    else:
        return_name = f'{first[0]} {lst[0]}'

        return return_name.lower()

# %%
polled['process_name'] = polled.apply(transform_name, axis=1)
# Out:
# /var/folders/_d/tnkg6yhj7xj4rxgh61bmdwtr0000gn/T/ipykernel_75544/2100486044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   polled['process_name'] = polled.apply(transform_name, axis=1)

# %%
new_df = pd.merge(polled, players, 
                  
        left_on=['process_name', 'player_team'],
        right_on=['process_name', 'player_team'], 
        how='left')

# 1 name represented incorrectly

len(new_df[new_df.isna().any(axis=1)])
# Out:
# 1

# %%
new_df[new_df.isna().any(axis=1)]
# Out:
#       home_team away_team  round_number first_name surname player_team  \
# 358  West Coast  Essendon            15     Willie   Rioli  West Coast
#
#      brownlow_votes process_name  season  player_id  no_teams  \
# 358               1      w rioli     NaN        NaN       NaN
#
#     player_first_name player_last_name
# 358               NaN              NaN

# %%
polled.query('surname.str.contains("Rioli")')
# Out:
#        home_team away_team  round_number first_name surname player_team  \
# 5489  West Coast  Essendon            15     Willie   Rioli  West Coast
#
#       brownlow_votes process_name
# 5489               1      w rioli

# %%
players.query('player_last_name.str.contains("Rioli")')
# Out:
#        season  player_id player_team  no_teams player_first_name  \
# 85069    2022      12409    Richmond         1            Daniel
# 85401    2022      12613  West Coast         1            Junior
# 87534    2022      12935    Richmond         1           Maurice
#
#       player_last_name process_name
# 85069            Rioli      d rioli
# 85401            Rioli      j rioli
# 87534            Rioli      m rioli

# %%
polled.loc[5489, ['first_name', 'process_name']] = 'Junior', 'j rioli'

# %%
# remerge datasets after altering player name
new_df = pd.merge(polled, players, 
                  
        left_on=['process_name', 'player_team'],
        right_on=['process_name', 'player_team'], 
        how='left')


len(new_df[new_df.isna().any(axis=1)])
# Out:
# 0

# %%
# top 20 looks correct as compared to aftables website
new_df.groupby(['player_id', 'player_first_name', 'player_last_name'])['brownlow_votes'].sum().reset_index().sort_values('brownlow_votes', ascending=False)[:20]
# Out:
#      player_id player_first_name player_last_name  brownlow_votes
# 71       12269           Patrick           Cripps              29
# 42       12061            Lachie            Neale              28
# 83       12329              Touk           Miller              27
# 150      12596            Andrew         Brayshaw              25
# 99       12411           Clayton           Oliver              25
# 109      12437         Christian         Petracca              24
# 102      12418            Callum            Mills              21
# 36       12022            Jeremy          Cameron              19
# 27       11921              Dion          Prestia              19
# 68       12249              Zach          Merrett              17
# 31       11958              Luke           Parker              16
# 92       12365              Karl             Amon              15
# 130      12526              Hugh       McCluggage              14
# 104      12421              Josh          Dunkley              14
# 181      12767              Noah         Anderson              14
# 170      12696            Connor            Rozee              14
# 166      12685               Sam            Walsh              14
# 30       11953               Tom            Lynch              14
# 12       11724            Taylor           Walker              14
# 55       12155             Ollie            Wines              13

# %%
new_df
# Out:
#      home_team         away_team  round_number first_name    surname  \
# 0    Melbourne  Western Bulldogs             1    Clayton     Oliver
# 1    Melbourne  Western Bulldogs             1  Christian   Petracca
# 2    Melbourne  Western Bulldogs             1       Jack     Macrae
# 3      Carlton          Richmond             1       Adam      Cerra
# 4      Carlton          Richmond             1    Patrick     Cripps
# ..         ...               ...           ...        ...        ...
# 589    Carlton       Collingwood            23    Patrick     Cripps
# 590    Carlton       Collingwood            23       Josh     Daicos
# 591   St Kilda            Sydney            23        Dan  Hannebery
# 592   St Kilda            Sydney            23        Ben       Long
# 593   St Kilda            Sydney            23       Jack     Steele
#
#           player_team  brownlow_votes process_name  season  player_id  \
# 0           Melbourne               1     c oliver    2022      12411
# 1           Melbourne               3   c petracca    2022      12437
# 2    Western Bulldogs               2     j macrae    2022      12172
# 3             Carlton               3      a cerra    2022      12610
# 4             Carlton               1     p cripps    2022      12269
# ..                ...             ...          ...     ...        ...
# 589           Carlton               3     p cripps    2022      12269
# 590       Collingwood               1     j daicos    2022      12582
# 591          St Kilda               3  d hannebery    2022      11787
# 592          St Kilda               2       b long    2022      12529
# 593          St Kilda               1     j steele    2022      12377
#
#      no_teams player_first_name player_last_name
# 0           1           Clayton           Oliver
# 1           1         Christian         Petracca
# 2           1              Jack           Macrae
# 3           2              Adam            Cerra
# 4           1           Patrick           Cripps
# ..        ...               ...              ...
# 589         1           Patrick           Cripps
# 590         1              Josh           Daicos
# 591         2               Dan        Hannebery
# 592         1               Ben             Long
# 593         2              Jack           Steele
#
# [594 rows x 13 columns]

# %%
new_df = new_df[['player_id', 'player_first_name', 'player_last_name', 'player_team', 'round_number', 'brownlow_votes']]

# %%
# will be used with 2023 data to get past polling perforamnce
new_df.to_parquet('../../data/curated/brownlow_votes_22.parquet')

# %%
new_df.drop(columns=['player_first_name', 'player_last_name', 'player_team'],inplace=True)
# Out:
# /var/folders/_d/tnkg6yhj7xj4rxgh61bmdwtr0000gn/T/ipykernel_75544/2492418099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['player_first_name', 'player_last_name', 'player_team'],inplace=True)

# %%
full_df = pd.read_csv('../../data/raw/stats_12-22_no_na.csv')

# %%
df_2022 = full_df.query('season == 2022').drop(columns='brownlow_votes')

# %%
df_2022 = pd.merge(df_2022, new_df,
         left_on=['player_id', 'match_round'],
         right_on=['player_id', 'round_number'],
         how='left').drop(columns='round_number')

# %%
# total players - players polled = n/a
# 22*9*46 - 22*9*3 = 8514 as expected
df_2022.isna().sum().sort_values(ascending=False)[:5]
# Out:
# brownlow_votes             8514
# score_involvements            0
# contest_def_one_on_ones       0
# contest_def_losses            0
# tackles_inside_fifty          0
# dtype: int64

# %%
df_2022.fillna(0, inplace=True)

# %%
full_df = full_df.query('season < 2022')
full_df
# Out:
#        match_id         match_home_team  match_away_team  match_date  \
# 0         13960  Greater Western Sydney           Sydney  2012-03-24
# 1         13960  Greater Western Sydney           Sydney  2012-03-24
# 2         13960  Greater Western Sydney           Sydney  2012-03-24
# 3         13960  Greater Western Sydney           Sydney  2012-03-24
# 4         13960  Greater Western Sydney           Sydney  2012-03-24
# ...         ...                     ...              ...         ...
# 85003     16105                Adelaide  North Melbourne  2021-08-22
# 85004     16105                Adelaide  North Melbourne  2021-08-22
# 85005     16105                Adelaide  North Melbourne  2021-08-22
# 85006     16105                Adelaide  North Melbourne  2021-08-22
# 85007     16105                Adelaide  North Melbourne  2021-08-22
#
#        match_round  match_home_team_goals  match_home_team_behinds  \
# 0                1                      5                        7
# 1                1                      5                        7
# 2                1                      5                        7
# 3                1                      5                        7
# 4                1                      5                        7
# ...            ...                    ...                      ...
# 85003           23                     13                       20
# 85004           23                     13                       20
# 85005           23                     13                       20
# 85006           23                     13                       20
# 85007           23                     13                       20
#
#        match_home_team_score  match_away_team_goals  match_away_team_behinds  \
# 0                         37                     14                       16
# 1                         37                     14                       16
# 2                         37                     14                       16
# 3                         37                     14                       16
# 4                         37                     14                       16
# ...                      ...                    ...                      ...
# 85003                     98                      8                        6
# 85004                     98                      8                        6
# 85005                     98                      8                        6
# 85006                     98                      8                        6
# 85007                     98                      8                        6
#
#        ...  intercept_marks  marks_on_lead pressure_acts  rating_points  \
# 0      ...              0.0            1.0          15.0           11.6
# 1      ...              0.0            2.0          12.0            9.8
# 2      ...              3.0            0.0          15.0           12.4
# 3      ...              1.0            0.0          23.0           15.9
# 4      ...              8.0            0.0           7.0           16.0
# ...    ...              ...            ...           ...            ...
# 85003  ...              0.0            0.0           8.0            6.8
# 85004  ...              0.0            1.0          15.0            3.2
# 85005  ...              0.0            0.0           6.0            9.5
# 85006  ...              0.0            0.0           9.0            4.5
# 85007  ...              0.0            0.0          10.0           -3.7
#
#       ruck_contests score_launches shots_at_goal  spoils  player_position  \
# 0               0.0            2.0           1.0     1.0                R
# 1               0.0            1.0           2.0     1.0              CHF
# 2               0.0            1.0           0.0     3.0               WR
# 3               0.0            2.0           1.0     0.0               RR
# 4               0.0            2.0           0.0     3.0              CHB
# ...             ...            ...           ...     ...              ...
# 85003          18.0            2.0           3.0     1.0              CHF
# 85004           0.0            0.0           1.0     0.0              FPL
# 85005           0.0            2.0           0.0     0.0               WL
# 85006           0.0            0.0           3.0     0.0              INT
# 85007           0.0            0.0           1.0     1.0              INT
#
#        season
# 0        2012
# 1        2012
# 2        2012
# 3        2012
# 4        2012
# ...       ...
# 85003    2021
# 85004    2021
# 85005    2021
# 85006    2021
# 85007    2021
#
# [85008 rows x 70 columns]

# %%
final_df = pd.concat([full_df, df_2022])

# %%
final_df
# Out:
#       match_id         match_home_team match_away_team  match_date  \
# 0        13960  Greater Western Sydney          Sydney  2012-03-24
# 1        13960  Greater Western Sydney          Sydney  2012-03-24
# 2        13960  Greater Western Sydney          Sydney  2012-03-24
# 3        13960  Greater Western Sydney          Sydney  2012-03-24
# 4        13960  Greater Western Sydney          Sydney  2012-03-24
# ...        ...                     ...             ...         ...
# 9103     16346                St Kilda          Sydney  2022-08-21
# 9104     16346                St Kilda          Sydney  2022-08-21
# 9105     16346                St Kilda          Sydney  2022-08-21
# 9106     16346                St Kilda          Sydney  2022-08-21
# 9107     16346                St Kilda          Sydney  2022-08-21
#
#       match_round  match_home_team_goals  match_home_team_behinds  \
# 0               1                      5                        7
# 1               1                      5                        7
# 2               1                      5                        7
# 3               1                      5                        7
# 4               1                      5                        7
# ...           ...                    ...                      ...
# 9103           23                     11                        8
# 9104           23                     11                        8
# 9105           23                     11                        8
# 9106           23                     11                        8
# 9107           23                     11                        8
#
#       match_home_team_score  match_away_team_goals  match_away_team_behinds  \
# 0                        37                     14                       16
# 1                        37                     14                       16
# 2                        37                     14                       16
# 3                        37                     14                       16
# 4                        37                     14                       16
# ...                     ...                    ...                      ...
# 9103                     74                     13                       10
# 9104                     74                     13                       10
# 9105                     74                     13                       10
# 9106                     74                     13                       10
# 9107                     74                     13                       10
#
#       ...  intercept_marks  marks_on_lead pressure_acts  rating_points  \
# 0     ...              0.0            1.0          15.0           11.6
# 1     ...              0.0            2.0          12.0            9.8
# 2     ...              3.0            0.0          15.0           12.4
# 3     ...              1.0            0.0          23.0           15.9
# 4     ...              8.0            0.0           7.0           16.0
# ...   ...              ...            ...           ...            ...
# 9103  ...              0.0            1.0           8.0            5.6
# 9104  ...              1.0            0.0          21.0            6.1
# 9105  ...              0.0            0.0          23.0            5.8
# 9106  ...              0.0            3.0          13.0            2.3
# 9107  ...              0.0            0.0          13.0            5.1
#
#      ruck_contests score_launches shots_at_goal  spoils  player_position  \
# 0              0.0            2.0           1.0     1.0                R
# 1              0.0            1.0           2.0     1.0              CHF
# 2              0.0            1.0           0.0     3.0               WR
# 3              0.0            2.0           1.0     0.0               RR
# 4              0.0            2.0           0.0     3.0              CHB
# ...            ...            ...           ...     ...              ...
# 9103           0.0            1.0           3.0     0.0              INT
# 9104           0.0            1.0           1.0     0.0              INT
# 9105           0.0            0.0           2.0     1.0              FPR
# 9106           0.0            2.0           2.0     0.0               WR
# 9107           0.0            0.0           1.0     0.0                C
#
#       season
# 0       2012
# 1       2012
# 2       2012
# 3       2012
# 4       2012
# ...      ...
# 9103    2022
# 9104    2022
# 9105    2022
# 9106    2022
# 9107    2022
#
# [94116 rows x 70 columns]

# %%
# all columns merged succesfully and columns are same between both dataframes
final_df.isna().sum()
# Out:
# match_id           0
# match_home_team    0
# match_away_team    0
# match_date         0
# match_round        0
#                   ..
# score_launches     0
# shots_at_goal      0
# spoils             0
# player_position    0
# season             0
# Length: 70, dtype: int64

# %%
final_df.to_parquet('../../data/raw/cleaned_stats_12-22_fixed_bv.parquet')
