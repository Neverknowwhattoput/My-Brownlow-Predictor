# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/raw/stats_12-22.csv')

# %%
df.head()
# Out:
#    match_id         match_home_team match_away_team  match_date  match_round  \
# 0     13960  Greater Western Sydney          Sydney  2012-03-24            1
# 1     13960  Greater Western Sydney          Sydney  2012-03-24            1
# 2     13960  Greater Western Sydney          Sydney  2012-03-24            1
# 3     13960  Greater Western Sydney          Sydney  2012-03-24            1
# 4     13960  Greater Western Sydney          Sydney  2012-03-24            1
#
#    match_home_team_goals  match_home_team_behinds  match_home_team_score  \
# 0                      5                        7                     37
# 1                      5                        7                     37
# 2                      5                        7                     37
# 3                      5                        7                     37
# 4                      5                        7                     37
#
# ...

# %%
df = df.astype({'match_date': 'datetime64[ns]'})

# %%
df['season'] = df.match_date.dt.year

# %%
len(df[df.isnull().any(axis=1)])
# Out:
# 889

# %%
# null values arise in these years:
df[df.isnull().any(axis=1)].season.unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2020, 2021], dtype=int32)

# %% [markdown]
# # Investigating 2012-2016 values
#
# It seems for whatever odd reason, there are 2 or 3 matches in each season where the advanced statistics were not recorded
# I have searched the official AFL website as well as other common sources such as afl tables and footywire, but they all return n/a.

# %%
df_2012 = df.query('season == 2012')
df_2012_na = df_2012[df_2012.isna().any(axis=1)]

# %%
df_2012.isna().sum().sort_values(ascending=False)[:25]
# Out:
# contest_off_wins           88
# ground_ball_gets           88
# score_involvements         88
# metres_gained              88
# turnovers                  88
# intercepts                 88
# tackles_inside_fifty       88
# contest_def_losses         88
# contest_def_one_on_ones    88
# contest_off_one_on_ones    88
# def_half_pressure_acts     88
# effective_kicks            88
# f50_ground_ball_gets       88
# hitouts_to_advantage       88
# hitout_win_percentage      88
# intercept_marks            88
# marks_on_lead              88
# pressure_acts              88
# ruck_contests              88
# score_launches             88
# shots_at_goal              88
# spoils                     88
# afl_fantasy_score           0
# bounces                     0
# one_percenters              0
# dtype: int64

# %%
# the n/a values arise in 2 matches: Adelaide, GWS in round 4 and GC, Carlton round 22
# it seems the values were not recorded as they are not present on the official AFL website, or any other data keeping site that I have seen

df_2012_na
# Out:
#       match_id match_home_team         match_away_team match_date  \
# 1320     13990        Adelaide  Greater Western Sydney 2012-04-21
# 1321     13990        Adelaide  Greater Western Sydney 2012-04-21
# 1322     13990        Adelaide  Greater Western Sydney 2012-04-21
# 1323     13990        Adelaide  Greater Western Sydney 2012-04-21
# 1324     13990        Adelaide  Greater Western Sydney 2012-04-21
# ...        ...             ...                     ...        ...
# 8135     14144      Gold Coast                 Carlton 2012-08-25
# 8136     14144      Gold Coast                 Carlton 2012-08-25
# 8137     14144      Gold Coast                 Carlton 2012-08-25
# 8138     14144      Gold Coast                 Carlton 2012-08-25
# 8139     14144      Gold Coast                 Carlton 2012-08-25
#
#       match_round  match_home_team_goals  match_home_team_behinds  \
# 1320            4                     13                       18
# ...

# %% [markdown]
# # 2013

# %%
df_2013 = df.query('season == 2013')
df_2013_na = df_2013[df_2013.isna().any(axis=1)]

# %%
df_2013.isna().sum().sort_values(ascending=False)[:25]
# Out:
# contest_off_wins           88
# ground_ball_gets           88
# score_involvements         88
# metres_gained              88
# turnovers                  88
# intercepts                 88
# tackles_inside_fifty       88
# contest_def_losses         88
# contest_def_one_on_ones    88
# contest_off_one_on_ones    88
# def_half_pressure_acts     88
# effective_kicks            88
# f50_ground_ball_gets       88
# hitouts_to_advantage       88
# hitout_win_percentage      88
# intercept_marks            88
# marks_on_lead              88
# pressure_acts              88
# ruck_contests              88
# score_launches             88
# shots_at_goal              88
# spoils                     88
# afl_fantasy_score           0
# bounces                     0
# one_percenters              0
# dtype: int64

# %%
df_2013_na
# Out:
#        match_id match_home_team  match_away_team match_date  match_round  \
# 9504      14185       Fremantle         Essendon 2013-04-12            3
# 9505      14185       Fremantle         Essendon 2013-04-12            3
# 9506      14185       Fremantle         Essendon 2013-04-12            3
# 9507      14185       Fremantle         Essendon 2013-04-12            3
# 9508      14185       Fremantle         Essendon 2013-04-12            3
# ...         ...             ...              ...        ...          ...
# 14515     14298  Brisbane Lions  North Melbourne 2013-07-13           16
# 14516     14298  Brisbane Lions  North Melbourne 2013-07-13           16
# 14517     14298  Brisbane Lions  North Melbourne 2013-07-13           16
# 14518     14298  Brisbane Lions  North Melbourne 2013-07-13           16
# 14519     14298  Brisbane Lions  North Melbourne 2013-07-13           16
#
#        match_home_team_goals  match_home_team_behinds  match_home_team_score  \
# ...

# %%
df_2014 = df.query('season == 2014')
df_2014_na = df_2014[df_2014.isna().any(axis=1)]

# %%
df_2014.isna().sum().sort_values(ascending=False)[:25]
# Out:
# contest_off_wins           88
# ground_ball_gets           88
# score_involvements         88
# metres_gained              88
# turnovers                  88
# intercepts                 88
# tackles_inside_fifty       88
# contest_def_losses         88
# contest_def_one_on_ones    88
# contest_off_one_on_ones    88
# def_half_pressure_acts     88
# effective_kicks            88
# f50_ground_ball_gets       88
# hitouts_to_advantage       88
# hitout_win_percentage      88
# intercept_marks            88
# marks_on_lead              88
# pressure_acts              88
# ruck_contests              88
# score_launches             88
# shots_at_goal              88
# spoils                     88
# afl_fantasy_score           0
# bounces                     0
# one_percenters              0
# dtype: int64

# %%
df_2014_na
# Out:
#        match_id match_home_team match_away_team match_date  match_round  \
# 20812     14451     Collingwood      West Coast 2014-05-24           10
# 20813     14451     Collingwood      West Coast 2014-05-24           10
# 20814     14451     Collingwood      West Coast 2014-05-24           10
# 20815     14451     Collingwood      West Coast 2014-05-24           10
# 20816     14451     Collingwood      West Coast 2014-05-24           10
# ...         ...             ...             ...        ...          ...
# 25207     14550     Collingwood  Brisbane Lions 2014-08-16           21
# 25208     14550     Collingwood  Brisbane Lions 2014-08-16           21
# 25209     14550     Collingwood  Brisbane Lions 2014-08-16           21
# 25210     14550     Collingwood  Brisbane Lions 2014-08-16           21
# 25211     14550     Collingwood  Brisbane Lions 2014-08-16           21
#
#        match_home_team_goals  match_home_team_behinds  match_home_team_score  \
# ...

# %%
df_2015 = df.query('season == 2015')
df_2015_na = df_2015[df_2015.isna().any(axis=1)]

# %%
df_2015.isna().sum().sort_values(ascending=False)[:25]
# Out:
# contest_off_wins             88
# intercept_marks              88
# contest_def_losses           88
# contest_def_one_on_ones      88
# contest_off_one_on_ones      88
# def_half_pressure_acts       88
# effective_kicks              88
# f50_ground_ball_gets         88
# ground_ball_gets             88
# hitout_win_percentage        88
# hitouts_to_advantage         88
# marks_on_lead                88
# pressure_acts                88
# ruck_contests                88
# score_launches               88
# spoils                       88
# score_involvements            0
# bounces                       0
# goal_assists                  0
# one_percenters                0
# marks_inside_fifty            0
# time_on_ground_percentage     0
# afl_fantasy_score             0
# centre_clearances             0
# stoppage_clearances           0
# dtype: int64

# %%
df_2015_na
# Out:
#        match_id match_home_team match_away_team match_date  match_round  \
# 26532     14590      West Coast         Carlton 2015-04-10            2
# 26533     14590      West Coast         Carlton 2015-04-10            2
# 26534     14590      West Coast         Carlton 2015-04-10            2
# 26535     14590      West Coast         Carlton 2015-04-10            2
# 26536     14590      West Coast         Carlton 2015-04-10            2
# ...         ...             ...             ...        ...          ...
# 31323     14698        Richmond         Carlton 2015-07-10           15
# 31324     14698        Richmond         Carlton 2015-07-10           15
# 31325     14698        Richmond         Carlton 2015-07-10           15
# 31326     14698        Richmond         Carlton 2015-07-10           15
# 31327     14698        Richmond         Carlton 2015-07-10           15
#
#        match_home_team_goals  match_home_team_behinds  match_home_team_score  \
# ...

# %%
df_2016 = df.query('season == 2016')
df_2016_na = df_2016[df_2016.isna().any(axis=1)]

# %%
df_2016.isna().sum().sort_values(ascending=False)[:25]
# Out:
# contest_off_wins             132
# intercept_marks              132
# contest_def_losses           132
# contest_def_one_on_ones      132
# contest_off_one_on_ones      132
# def_half_pressure_acts       132
# effective_kicks              132
# f50_ground_ball_gets         132
# ground_ball_gets             132
# hitout_win_percentage        132
# hitouts_to_advantage         132
# marks_on_lead                132
# pressure_acts                132
# ruck_contests                132
# score_launches               132
# spoils                       132
# score_involvements             0
# bounces                        0
# goal_assists                   0
# one_percenters                 0
# marks_inside_fifty             0
# time_on_ground_percentage      0
# afl_fantasy_score              0
# centre_clearances              0
# stoppage_clearances            0
# dtype: int64

# %%
df_2016_na.iloc[[0, 60, 130]]
# Out:
#        match_id match_home_team match_away_team match_date  match_round  \
# 34980     14791          Sydney     Collingwood 2016-03-26            1
# 37592     14850        Adelaide         Geelong 2016-05-13            8
# 40522     14916      Gold Coast  Brisbane Lions 2016-07-09           16
#
#        match_home_team_goals  match_home_team_behinds  match_home_team_score  \
# 34980                     18                       25                    133
# 37592                     11                        6                     72
# 40522                     22                        7                    139
#
#        match_away_team_goals  match_away_team_behinds  ...  intercept_marks  \
# 34980                      7                       11  ...              NaN
# 37592                     13                       20  ...              NaN
# 40522                     17                       11  ...              NaN
#
# ...

# %% [markdown]
# # Investigating 2020-2021 values

# %%
df_2020 = df.query('season == 2020')
df_2020_na = df_2020[df_2020.isna().any(axis=1)]

# %%
df_2020.isna().sum().sort_values(ascending=False)[:2]
# Out:
# afl_fantasy_score    395
# match_id               0
# dtype: int64

# %%
# afl fantasy scores were not recorded in dataset in all 9 round 1 matches
len(df_2020_na.match_id.unique())
# Out:
# 9

# %%
idx_to_change = df_2020_na.index

# %%
# calculate fantasy score via formula on afl website
# https://www.fantasy.afl.com.au/classic/help/game-guidelines

df.loc[idx_to_change, 'afl_fantasy_score'] = 3*df['kicks'] + 2*df['handballs'] \
                                            + 3*df['marks'] +4*df['tackles'] \
                                            + 1*df['free_kicks_for'] \
                                            - 3*df['free_kicks_against'] \
                                            + df['hitouts'] \
                                            + 6*df['goals'] \
                                            + 1*df['behinds']

# %%
# visible values agree with AFL website
df.loc[idx_to_change][['player_first_name', 'player_last_name', 'afl_fantasy_score']]
# Out:
#       player_first_name player_last_name  afl_fantasy_score
# 69652              Kade          Simpson               72.0
# 69653              Marc           Murphy               78.0
# 69654             Shane          Edwards               52.0
# 69655              Jack         Riewoldt               50.0
# 69656           Matthew          Kreuzer               16.0
# ...                 ...              ...                ...
# 70043              Jack      Petruccelle               36.0
# 70044            Jarrod          Brander               61.0
# 70045               Jay         Lockhart               42.0
# 70046              Toby          Bedford               26.0
# 70047           Kysaiah          Pickett               44.0
#
# [395 rows x 3 columns]

# %% [markdown]
# # Editing 2021 values

# %%
df_2021 = df.query('season == 2021')

# %%
df_2021_na = df_2021[df_2021.isna().any(axis=1)]

# %%
# only 10 player's rating points are missing
df_2021.isna().sum().sort_values(ascending=False)[:2]
# Out:
# rating_points    10
# match_id          0
# dtype: int64

# %%
col = [
    'match_home_team', 'match_away_team', 'match_round',
    'player_first_name', 'player_last_name', 'rating_points', 'disposals'
]

# %%
# create table to easily find missing values on AFL website
df_2021_na[col]
# Out:
#         match_home_team         match_away_team  match_round  \
# 78198            Sydney  Greater Western Sydney            5
# 78644         Melbourne                Richmond            6
# 79874        Gold Coast          Brisbane Lions            9
# 79993          Essendon               Fremantle            9
# 80297  Western Bulldogs                St Kilda           10
# 82092        West Coast        Western Bulldogs           15
# 82155           Carlton                Adelaide           15
# 83861          St Kilda                 Carlton           20
# 84619        West Coast               Melbourne           21
# 85073         Fremantle              West Coast           22
#
#       player_first_name player_last_name  rating_points  disposals
# 78198            Oliver          Florent            NaN         15
# 78644              Jake         Melksham            NaN         11
# 79874              Izak          Rankine            NaN          5
# ...

# %%
# fortunately, only 10 errors means it is easy to source by hand
rating_points_in_order = [
    7.3,
    0.5,
    2.8,
    19.8,
    3.3,
    10.6,
    4.8,
    8.5,
    14.3,
    5.5
]

# %%
idx_to_change = df_2021_na.index

# %%
df.loc[idx_to_change, 'rating_points'] = rating_points_in_order

# %%
# check values entered as intended
df.loc[idx_to_change, ['player_last_name', 'rating_points']]
# Out:
#       player_last_name  rating_points
# 78198          Florent            7.3
# 78644         Melksham            0.5
# 79874          Rankine            2.8
# 79993           Parish           19.8
# 80297         McKernan            3.3
# 82092            Shuey           10.6
# 82155          Kennedy            4.8
# 83861       Williamson            8.5
# 84619          Kennedy           14.3
# 85073            Foley            5.5

# %% [markdown]
# # Final Comments

# %% [markdown]
# To begin, there was 889 total rows of n/a values
# After investigating the reason for the missing values, only 484 remain.
#
# These 484 correspond with 11 games * 44 players where individual statistics were simply
# not recorded during the play. This means a total of 33 brownlow polling performances will not
# be learned by the model.
#
# Fortunately the missing performances occured in 2012-1016 and therefore do not impact
# the years 2021 and 2022, which will be used for testing the model.

# %%
df[df.isna().any(axis=1)]
# Out:
#        match_id match_home_team         match_away_team match_date  \
# 1320      13990        Adelaide  Greater Western Sydney 2012-04-21
# 1321      13990        Adelaide  Greater Western Sydney 2012-04-21
# 1322      13990        Adelaide  Greater Western Sydney 2012-04-21
# 1323      13990        Adelaide  Greater Western Sydney 2012-04-21
# 1324      13990        Adelaide  Greater Western Sydney 2012-04-21
# ...         ...             ...                     ...        ...
# 40519     14916      Gold Coast          Brisbane Lions 2016-07-09
# 40520     14916      Gold Coast          Brisbane Lions 2016-07-09
# 40521     14916      Gold Coast          Brisbane Lions 2016-07-09
# 40522     14916      Gold Coast          Brisbane Lions 2016-07-09
# 40523     14916      Gold Coast          Brisbane Lions 2016-07-09
#
#        match_round  match_home_team_goals  match_home_team_behinds  \
# 1320             4                     13                       18
# ...

# %%
df.dropna(inplace=True)

# %%
df.to_csv('../../data/raw/stats_12-22_no_na.csv', index=False)
