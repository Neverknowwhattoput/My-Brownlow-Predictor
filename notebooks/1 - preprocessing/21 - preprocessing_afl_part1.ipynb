# %% [markdown]
# # Preprocessing 2023 AFL data
#
# Cleaning the data sourced from the offical AFL website
#
# We rename the columns and remove any duplicate/unimportant columns.

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/landing/player_stats_23_afl.csv', index_col=0)
# Out:
# /var/folders/_d/tnkg6yhj7xj4rxgh61bmdwtr0000gn/T/ipykernel_13114/239255809.py:1: DtypeWarning: Columns (16,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/landing/player_stats_23_afl.csv', index_col=0)

# %%
df
# Out:
#            providerId                  utcStartTime     status  \
# 1     CD_M20230140101  2023-03-16T08:20:00.000+0000  CONCLUDED
# 2     CD_M20230140101  2023-03-16T08:20:00.000+0000  CONCLUDED
# 3     CD_M20230140101  2023-03-16T08:20:00.000+0000  CONCLUDED
# 4     CD_M20230140101  2023-03-16T08:20:00.000+0000  CONCLUDED
# 5     CD_M20230140101  2023-03-16T08:20:00.000+0000  CONCLUDED
# ...               ...                           ...        ...
# 9887  CD_M20230142702  2023-09-23T07:15:00.000+0000  CONCLUDED
# 9888  CD_M20230142702  2023-09-23T07:15:00.000+0000  CONCLUDED
# 9889  CD_M20230142702  2023-09-23T07:15:00.000+0000  CONCLUDED
# 9890  CD_M20230142702  2023-09-23T07:15:00.000+0000  CONCLUDED
# 9891  CD_M20230142801  2023-09-30T04:30:00.000+0000  SCHEDULED
#
#      compSeason.shortName          round.name  round.roundNumber venue.name  \
# 1             Premiership             Round 1                  1        MCG
# 2             Premiership             Round 1                  1        MCG
# 3             Premiership             Round 1                  1        MCG
# 4             Premiership             Round 1                  1        MCG
# 5             Premiership             Round 1                  1        MCG
# ...                   ...                 ...                ...        ...
# 9887          Premiership  Preliminary Finals                 27      Gabba
# 9888          Premiership  Preliminary Finals                 27      Gabba
# 9889          Premiership  Preliminary Finals                 27      Gabba
# 9890          Premiership  Preliminary Finals                 27      Gabba
# 9891          Premiership         Grand Final                 28        MCG
#
#       home.team.name home.team.club.name  away.team.name  ...  \
# 1           Richmond            Richmond         Carlton  ...
# 2           Richmond            Richmond         Carlton  ...
# 3           Richmond            Richmond         Carlton  ...
# 4           Richmond            Richmond         Carlton  ...
# 5           Richmond            Richmond         Carlton  ...
# ...              ...                 ...             ...  ...
# 9887  Brisbane Lions      Brisbane Lions         Carlton  ...
# 9888  Brisbane Lions      Brisbane Lions         Carlton  ...
# 9889  Brisbane Lions      Brisbane Lions         Carlton  ...
# 9890  Brisbane Lions      Brisbane Lions         Carlton  ...
# 9891     Collingwood         Collingwood  Brisbane Lions  ...
#
#      extendedStats.centreBounceAttendances  extendedStats.kickins  \
# 1                                      0.0                    1.0
# 2                                      0.0                    0.0
# 3                                     11.0                    0.0
# 4                                      0.0                    0.0
# 5                                      6.0                    0.0
# ...                                    ...                    ...
# 9887                                   3.0                    0.0
# 9888                                  15.0                    0.0
# 9889                                   0.0                    0.0
# 9890                                   6.0                    0.0
# 9891                                   NaN                    NaN
#
#      extendedStats.kickinsPlayon player.playerId player.captain  \
# 1                            1.0     CD_I1000223          False
# 2                            0.0     CD_I1002245          False
# 3                            0.0      CD_I993993          False
# 4                            0.0      CD_I295203          False
# 5                            0.0      CD_I270896          False
# ...                          ...             ...            ...
# 9887                         0.0     CD_I1004912          False
# 9888                         0.0      CD_I294036          False
# 9889                         0.0      CD_I996731          False
# 9890                         0.0     CD_I1001398          False
# 9891                         NaN             NaN            NaN
#
#      player.playerJumperNumber  player.givenName player.surname teamStatus  \
# 1                          7.0              Liam          Baker       home
# 2                         21.0              Noah          Balta       home
# 3                         29.0              Shai         Bolton       home
# 4                         35.0            Nathan          Broad       home
# 5                          9.0             Trent        Cotchin       home
# ...                        ...               ...            ...        ...
# 9887                      12.0               Tom      De Koning       away
# 9888                      29.0            George         Hewett       away
# 9889                      30.0           Charlie         Curnow       away
# 9890                       7.0           Matthew        Kennedy       away
# 9891                       NaN               NaN            NaN        NaN
#
#      team.name
# 1     Richmond
# 2     Richmond
# 3     Richmond
# 4     Richmond
# 5     Richmond
# ...        ...
# 9887   Carlton
# 9888   Carlton
# 9889   Carlton
# 9890   Carlton
# 9891       NaN
#
# [9891 rows x 95 columns]

# %%
df.columns
# Out:
# Index(['providerId', 'utcStartTime', 'status', 'compSeason.shortName',
#        'round.name', 'round.roundNumber', 'venue.name', 'home.team.name',
#        'home.team.club.name', 'away.team.name', 'away.team.club.name',
#        'player.jumperNumber', 'player.photoURL', 'player.player.position',
#        'player.player.player.playerId', 'player.player.player.captain',
#        'player.player.player.playerJumperNumber',
#        'player.player.player.givenName', 'player.player.player.surname',
#        'teamId', 'gamesPlayed', 'timeOnGroundPercentage', 'goals', 'behinds',
#        'superGoals', 'kicks', 'handballs', 'disposals', 'marks', 'bounces',
#        'tackles', 'contestedPossessions', 'uncontestedPossessions',
#        'totalPossessions', 'inside50s', 'marksInside50', 'contestedMarks',
#        'hitouts', 'onePercenters', 'disposalEfficiency', 'clangers',
#        'freesFor', 'freesAgainst', 'dreamTeamPoints', 'rebound50s',
#        'goalAssists', 'goalAccuracy', 'ratingPoints', 'ranking', 'lastUpdated',
#        'turnovers', 'intercepts', 'tacklesInside50', 'shotsAtGoal',
#        'goalEfficiency', 'shotEfficiency', 'interchangeCounts',
#        'scoreInvolvements', 'metresGained', 'clearances.centreClearances',
#        'clearances.stoppageClearances', 'clearances.totalClearances',
#        'extendedStats.effectiveKicks', 'extendedStats.kickEfficiency',
#        'extendedStats.kickToHandballRatio', 'extendedStats.effectiveDisposals',
#        'extendedStats.marksOnLead', 'extendedStats.interceptMarks',
#        'extendedStats.contestedPossessionRate',
#        'extendedStats.hitoutsToAdvantage', 'extendedStats.hitoutWinPercentage',
#        'extendedStats.hitoutToAdvantageRate', 'extendedStats.groundBallGets',
#        'extendedStats.f50GroundBallGets', 'extendedStats.scoreLaunches',
#        'extendedStats.pressureActs', 'extendedStats.defHalfPressureActs',
#        'extendedStats.spoils', 'extendedStats.ruckContests',
#        'extendedStats.contestDefOneOnOnes', 'extendedStats.contestDefLosses',
#        'extendedStats.contestDefLossPercentage',
#        'extendedStats.contestOffOneOnOnes', 'extendedStats.contestOffWins',
#        'extendedStats.contestOffWinsPercentage',
#        'extendedStats.centreBounceAttendances', 'extendedStats.kickins',
#        'extendedStats.kickinsPlayon', 'player.playerId', 'player.captain',
#        'player.playerJumperNumber', 'player.givenName', 'player.surname',
#        'teamStatus', 'team.name'],
#       dtype='object')

# %%
for col in df.columns:
    print(f"'{col}': '{col.lower().replace('.','_')}',")
# Out:
# 'providerId': 'providerid',
# 'utcStartTime': 'utcstarttime',
# 'status': 'status',
# 'compSeason.shortName': 'compseason_shortname',
# 'round.name': 'round_name',
# 'round.roundNumber': 'round_roundnumber',
# 'venue.name': 'venue_name',
# 'home.team.name': 'home_team_name',
# 'home.team.club.name': 'home_team_club_name',
# 'away.team.name': 'away_team_name',
# 'away.team.club.name': 'away_team_club_name',
# 'player.jumperNumber': 'player_jumpernumber',
# 'player.photoURL': 'player_photourl',
# 'player.player.position': 'player_player_position',
# 'player.player.player.playerId': 'player_player_player_playerid',
# 'player.player.player.captain': 'player_player_player_captain',
# 'player.player.player.playerJumperNumber': 'player_player_player_playerjumpernumber',
# 'player.player.player.givenName': 'player_player_player_givenname',
# 'player.player.player.surname': 'player_player_player_surname',
# 'teamId': 'teamid',
# 'gamesPlayed': 'gamesplayed',
# 'timeOnGroundPercentage': 'timeongroundpercentage',
# 'goals': 'goals',
# 'behinds': 'behinds',
# 'superGoals': 'supergoals',
# 'kicks': 'kicks',
# 'handballs': 'handballs',
# 'disposals': 'disposals',
# 'marks': 'marks',
# 'bounces': 'bounces',
# 'tackles': 'tackles',
# 'contestedPossessions': 'contestedpossessions',
# 'uncontestedPossessions': 'uncontestedpossessions',
# 'totalPossessions': 'totalpossessions',
# 'inside50s': 'inside50s',
# 'marksInside50': 'marksinside50',
# 'contestedMarks': 'contestedmarks',
# 'hitouts': 'hitouts',
# 'onePercenters': 'onepercenters',
# 'disposalEfficiency': 'disposalefficiency',
# 'clangers': 'clangers',
# 'freesFor': 'freesfor',
# 'freesAgainst': 'freesagainst',
# 'dreamTeamPoints': 'dreamteampoints',
# 'rebound50s': 'rebound50s',
# 'goalAssists': 'goalassists',
# 'goalAccuracy': 'goalaccuracy',
# 'ratingPoints': 'ratingpoints',
# 'ranking': 'ranking',
# 'lastUpdated': 'lastupdated',
# 'turnovers': 'turnovers',
# 'intercepts': 'intercepts',
# 'tacklesInside50': 'tacklesinside50',
# 'shotsAtGoal': 'shotsatgoal',
# 'goalEfficiency': 'goalefficiency',
# 'shotEfficiency': 'shotefficiency',
# 'interchangeCounts': 'interchangecounts',
# 'scoreInvolvements': 'scoreinvolvements',
# 'metresGained': 'metresgained',
# 'clearances.centreClearances': 'clearances_centreclearances',
# 'clearances.stoppageClearances': 'clearances_stoppageclearances',
# 'clearances.totalClearances': 'clearances_totalclearances',
# 'extendedStats.effectiveKicks': 'extendedstats_effectivekicks',
# 'extendedStats.kickEfficiency': 'extendedstats_kickefficiency',
# 'extendedStats.kickToHandballRatio': 'extendedstats_kicktohandballratio',
# 'extendedStats.effectiveDisposals': 'extendedstats_effectivedisposals',
# 'extendedStats.marksOnLead': 'extendedstats_marksonlead',
# 'extendedStats.interceptMarks': 'extendedstats_interceptmarks',
# 'extendedStats.contestedPossessionRate': 'extendedstats_contestedpossessionrate',
# 'extendedStats.hitoutsToAdvantage': 'extendedstats_hitoutstoadvantage',
# 'extendedStats.hitoutWinPercentage': 'extendedstats_hitoutwinpercentage',
# 'extendedStats.hitoutToAdvantageRate': 'extendedstats_hitouttoadvantagerate',
# 'extendedStats.groundBallGets': 'extendedstats_groundballgets',
# 'extendedStats.f50GroundBallGets': 'extendedstats_f50groundballgets',
# 'extendedStats.scoreLaunches': 'extendedstats_scorelaunches',
# 'extendedStats.pressureActs': 'extendedstats_pressureacts',
# 'extendedStats.defHalfPressureActs': 'extendedstats_defhalfpressureacts',
# 'extendedStats.spoils': 'extendedstats_spoils',
# 'extendedStats.ruckContests': 'extendedstats_ruckcontests',
# 'extendedStats.contestDefOneOnOnes': 'extendedstats_contestdefoneonones',
# 'extendedStats.contestDefLosses': 'extendedstats_contestdeflosses',
# 'extendedStats.contestDefLossPercentage': 'extendedstats_contestdeflosspercentage',
# 'extendedStats.contestOffOneOnOnes': 'extendedstats_contestoffoneonones',
# 'extendedStats.contestOffWins': 'extendedstats_contestoffwins',
# 'extendedStats.contestOffWinsPercentage': 'extendedstats_contestoffwinspercentage',
# 'extendedStats.centreBounceAttendances': 'extendedstats_centrebounceattendances',
# 'extendedStats.kickins': 'extendedstats_kickins',
# 'extendedStats.kickinsPlayon': 'extendedstats_kickinsplayon',
# 'player.playerId': 'player_playerid',
# 'player.captain': 'player_captain',
# 'player.playerJumperNumber': 'player_playerjumpernumber',
# 'player.givenName': 'player_givenname',
# 'player.surname': 'player_surname',
# 'teamStatus': 'teamstatus',
# 'team.name': 'team_name',

# %%
df = df.rename(columns={
    'providerId': 'provider_id',
    'utcStartTime': 'utcstarttime',
    'status': 'status',
    'compSeason.shortName': 'compseason_shortname',
    'round.name': 'round_name',
    'round.roundNumber': 'round_number',
    'venue.name': 'venue_name',
    'home.team.name': 'home_team_name',
    'home.team.club.name': 'home_team_club_name',
    'away.team.name': 'away_team_name',
    'away.team.club.name': 'away_team_club_name',
    'player.jumperNumber': 'player_jumpernumber',
    'player.photoURL': 'player_photourl',
    'player.player.position': 'player_position',
    'player.player.player.playerId': 'player_id',
    'player.player.player.captain': 'player_captain',
    'player.player.player.playerJumperNumber': 'playerjumpernumber',
    'player.player.player.givenName': 'player_first_name',
    'player.player.player.surname': 'player_last_name',
    'teamId': 'teamid',
    'gamesPlayed': 'gamesplayed',
    'timeOnGroundPercentage': 'timeongroundpercentage',
    'goals': 'goals',
    'behinds': 'behinds',
    'superGoals': 'supergoals',
    'kicks': 'kicks',
    'handballs': 'handballs',
    'disposals': 'disposals',
    'marks': 'marks',
    'bounces': 'bounces',
    'tackles': 'tackles',
    'contestedPossessions': 'contested_possessions',
    'uncontestedPossessions': 'uncontested_possessions',
    'totalPossessions': 'total_possessions',
    'inside50s': 'inside_fifties',
    'marksInside50': 'marks_inside_fifty',
    'contestedMarks': 'contested_marks',
    'hitouts': 'hitouts',
    'onePercenters': 'one_percenters',
    'disposalEfficiency': 'disposal_efficiency',
    'clangers': 'clangers',
    'freesFor': 'free_kicks_for',
    'freesAgainst': 'free_kicks_against',
    'dreamTeamPoints': 'afl_fantasy_score',
    'rebound50s': 'rebounds',
    'goalAssists': 'goal_assists',
    'goalAccuracy': 'goal_accuracy',
    'ratingPoints': 'rating_points',
    'ranking': 'ranking',
    'lastUpdated': 'lastupdated',
    'turnovers': 'turnovers',
    'intercepts': 'intercepts',
    'tacklesInside50': 'tackles_inside_fifty',
    'shotsAtGoal': 'shots_at_goal',
    'goalEfficiency': 'goalefficiency',
    'shotEfficiency': 'shotefficiency',
    'interchangeCounts': 'interchangecounts',
    'scoreInvolvements': 'score_involvements',
    'metresGained': 'metres_gained',
    'clearances.centreClearances': 'centre_clearances',
    'clearances.stoppageClearances': 'stoppage_clearances',
    'clearances.totalClearances': 'clearances',
    'extendedStats.effectiveKicks': 'effective_kicks',
    'extendedStats.kickEfficiency': 'kick_efficiency',
    'extendedStats.kickToHandballRatio': 'kicktohandballratio',
    'extendedStats.effectiveDisposals': 'effective_disposals',
    'extendedStats.marksOnLead': 'marks_on_lead',
    'extendedStats.interceptMarks': 'intercept_marks',
    'extendedStats.contestedPossessionRate': 'contested_possessionrate',
    'extendedStats.hitoutsToAdvantage': 'hitouts_to_advantage',
    'extendedStats.hitoutWinPercentage': 'hitout_win_percentage',
    'extendedStats.hitoutToAdvantageRate': 'hitout_to_advantage_rate',
    'extendedStats.groundBallGets': 'ground_ball_gets',
    'extendedStats.f50GroundBallGets': 'f50_ground_ball_gets',
    'extendedStats.scoreLaunches': 'score_launches',
    'extendedStats.pressureActs': 'pressure_acts',
    'extendedStats.defHalfPressureActs': 'def_half_pressure_acts',
    'extendedStats.spoils': 'spoils',
    'extendedStats.ruckContests': 'ruckcontests',
    'extendedStats.contestDefOneOnOnes': 'contest_def_one_on_ones',
    'extendedStats.contestDefLosses': 'contest_def_losses',
    'extendedStats.contestDefLossPercentage': 'contestdeflosspercentage',
    'extendedStats.contestOffOneOnOnes': 'contest_off_one_on_ones',
    'extendedStats.contestOffWins': 'contest_off_wins',
    'extendedStats.contestOffWinsPercentage': 'contest_off_wins_percentage',
    'extendedStats.centreBounceAttendances': 'centre_bounce_attendances',
    'extendedStats.kickins': 'kickins',
    'extendedStats.kickinsPlayon': 'kickinsplayon',
    'player.playerId': 'playerid',
    
    'player.captain': 'is_captain',

    'player.playerJumperNumber': 'playerjumpernumber',
    'player.givenName': 'player_givenname',
    'player.surname': 'player_surname',
    'teamStatus': 'teamstatus',
    'team.name': 'team_name'
})

# %%
df.columns
# Out:
# Index(['provider_id', 'utcstarttime', 'status', 'compseason_shortname',
#        'round_name', 'round_number', 'venue_name', 'home_team_name',
#        'home_team_club_name', 'away_team_name', 'away_team_club_name',
#        'player_jumpernumber', 'player_photourl', 'player_position',
#        'player_id', 'player_captain', 'playerjumpernumber',
#        'player_first_name', 'player_last_name', 'teamid', 'gamesplayed',
#        'timeongroundpercentage', 'goals', 'behinds', 'supergoals', 'kicks',
#        'handballs', 'disposals', 'marks', 'bounces', 'tackles',
#        'contested_possessions', 'uncontested_possessions', 'total_possessions',
#        'inside_fifties', 'marks_inside_fifty', 'contested_marks', 'hitouts',
#        'one_percenters', 'disposal_efficiency', 'clangers', 'free_kicks_for',
#        'free_kicks_against', 'afl_fantasy_score', 'rebounds', 'goal_assists',
#        'goal_accuracy', 'rating_points', 'ranking', 'lastupdated', 'turnovers',
#        'intercepts', 'tackles_inside_fifty', 'shots_at_goal', 'goalefficiency',
#        'shotefficiency', 'interchangecounts', 'score_involvements',
#        'metres_gained', 'centre_clearances', 'stoppage_clearances',
#        'clearances', 'effective_kicks', 'kick_efficiency',
#        'kicktohandballratio', 'effective_disposals', 'marks_on_lead',
#        'intercept_marks', 'contested_possessionrate', 'hitouts_to_advantage',
#        'hitout_win_percentage', 'hitout_to_advantage_rate', 'ground_ball_gets',
#        'f50_ground_ball_gets', 'score_launches', 'pressure_acts',
#        'def_half_pressure_acts', 'spoils', 'ruckcontests',
#        'contest_def_one_on_ones', 'contest_def_losses',
#        'contestdeflosspercentage', 'contest_off_one_on_ones',
#        'contest_off_wins', 'contest_off_wins_percentage',
#        'centre_bounce_attendances', 'kickins', 'kickinsplayon', 'playerid',
#        'is_captain', 'playerjumpernumber', 'player_givenname',
#        'player_surname', 'teamstatus', 'team_name'],
#       dtype='object')

# %%
# remove finals matches
df = df.query('round_name.str.contains("Round")')

# %%
# remove duplicate columns and anything not relevant
cols_keep = [
    'round_number', 'venue_name',
    'home_team_name', 'away_team_name',
    'playerid', 'player_position',
    'player_first_name', 'player_last_name', 'teamid', 'team_name', 

    'timeongroundpercentage', 
    
    # player stats
    'goals', 'behinds', 'kicks',
    'handballs', 'disposals', 'marks', 'bounces', 'tackles',
    'contested_possessions', 'uncontested_possessions',
    'inside_fifties', 'marks_inside_fifty', 'contested_marks', 'hitouts',
    'one_percenters', 'disposal_efficiency', 'clangers', 'free_kicks_for',
    'free_kicks_against', 'afl_fantasy_score', 'rebounds', 'goal_assists',
    'rating_points', 'turnovers',
    'intercepts', 'tackles_inside_fifty',
     'score_involvements',
    'metres_gained', 'centre_clearances', 'stoppage_clearances',
    'clearances', 'effective_kicks', 'effective_disposals', 'marks_on_lead',
    'intercept_marks', 'hitouts_to_advantage',
    'hitout_win_percentage', 'ground_ball_gets',
    'f50_ground_ball_gets', 'score_launches', 'pressure_acts',
    'def_half_pressure_acts', 'spoils', 
    'contest_def_one_on_ones', 'contest_def_losses',
    'contest_off_one_on_ones',
    'contest_off_wins'
]

# %%
df = df[cols_keep]

# %%
matches = pd.DataFrame(df.groupby(['round_number', 'home_team_name']).sum()).sort_values(['round_number', 'home_team_name'])
match_id = [i for i in range(10_000, 10_000 + 23*9)]
matches['match_id'] = match_id

# %%
matches = matches['match_id']

# %%
df = pd.merge(df, matches, on=['round_number', 'home_team_name'])

# %%
df.head()
# Out:
#    round_number venue_name home_team_name away_team_name     playerid  \
# 0             1        MCG       Richmond        Carlton  CD_I1000223
# 1             1        MCG       Richmond        Carlton  CD_I1002245
# 2             1        MCG       Richmond        Carlton   CD_I993993
# 3             1        MCG       Richmond        Carlton   CD_I295203
# 4             1        MCG       Richmond        Carlton   CD_I270896
#
#   player_position player_first_name player_last_name   teamid team_name  ...  \
# 0             CHB              Liam            Baker  CD_T120  Richmond  ...
# 1             BPL              Noah            Balta  CD_T120  Richmond  ...
# 2            HFFR              Shai           Bolton  CD_T120  Richmond  ...
# 3            HBFL            Nathan            Broad  CD_T120  Richmond  ...
# 4             INT             Trent          Cotchin  CD_T120  Richmond  ...
#
#    f50_ground_ball_gets  score_launches  pressure_acts  \
# 0                   1.0             0.0           12.0
# 1                   0.0             0.0            7.0
# 2                   0.0             0.0            8.0
# 3                   0.0             0.0            6.0
# 4                   2.0             0.0           15.0
#
#    def_half_pressure_acts  spoils  contest_def_one_on_ones  \
# 0                    10.0     0.0                      2.0
# 1                     7.0     2.0                      3.0
# 2                     1.0     0.0                      0.0
# 3                     3.0     3.0                      2.0
# 4                     6.0     1.0                      0.0
#
#    contest_def_losses  contest_off_one_on_ones  contest_off_wins  match_id
# 0                 2.0                      0.0               0.0     10007
# 1                 2.0                      0.0               0.0     10007
# 2                 0.0                      2.0               0.0     10007
# 3                 0.0                      0.0               0.0     10007
# 4                 0.0                      0.0               0.0     10007
#
# [5 rows x 59 columns]

# %%
df.drop_duplicates('match_id')[['match_id', 'round_number', 'home_team_name', 'away_team_name']]
# Out:
#       match_id  round_number     home_team_name     away_team_name
# 0        10007             1           Richmond            Carlton
# 46       10001             1       Geelong Cats        Collingwood
# 92       10005             1    North Melbourne  West Coast Eagles
# 138      10006             1      Port Adelaide     Brisbane Lions
# 184      10004             1          Melbourne   Western Bulldogs
# ...        ...           ...                ...                ...
# 9292     10201            24       Geelong Cats   Western Bulldogs
# 9338     10206            24  West Coast Eagles     Adelaide Crows
# 9384     10204            24      Port Adelaide           Richmond
# 9430     10205            24       Sydney Swans          Melbourne
# 9476     10199            24            Carlton         GWS Giants
#
# [207 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['round_number', 'venue_name', 'home_team_name', 'away_team_name',
#        'playerid', 'player_position', 'player_first_name', 'player_last_name',
#        'teamid', 'team_name', 'timeongroundpercentage', 'goals', 'behinds',
#        'kicks', 'handballs', 'disposals', 'marks', 'bounces', 'tackles',
#        'contested_possessions', 'uncontested_possessions', 'inside_fifties',
#        'marks_inside_fifty', 'contested_marks', 'hitouts', 'one_percenters',
#        'disposal_efficiency', 'clangers', 'free_kicks_for',
#        'free_kicks_against', 'afl_fantasy_score', 'rebounds', 'goal_assists',
#        'rating_points', 'turnovers', 'intercepts', 'tackles_inside_fifty',
#        'score_involvements', 'metres_gained', 'centre_clearances',
#        'stoppage_clearances', 'clearances', 'effective_kicks',
#        'effective_disposals', 'marks_on_lead', 'intercept_marks',
#        'hitouts_to_advantage', 'hitout_win_percentage', 'ground_ball_gets',
#        'f50_ground_ball_gets', 'score_launches', 'pressure_acts',
#        'def_half_pressure_acts', 'spoils', 'contest_def_one_on_ones',
#        'contest_def_losses', 'contest_off_one_on_ones', 'contest_off_wins',
#        'match_id'],
#       dtype='object')

# %%
reorder_cols = [
    'match_id', 'round_number', 'venue_name', 'home_team_name', 'away_team_name',
       'playerid', 'player_first_name', 'player_last_name',
       'teamid', 'team_name', 'timeongroundpercentage', 
       
       'kicks', 'marks', 'handballs', 'disposals',
       'effective_disposals', 'goals',
       'behinds', 'hitouts', 'tackles', 'rebounds', 'inside_fifties',
       'clearances', 'clangers', 'free_kicks_for', 'free_kicks_against',
       'contested_possessions', 'uncontested_possessions',
       'contested_marks', 'marks_inside_fifty', 'one_percenters', 'bounces',
       'goal_assists', 'afl_fantasy_score',
       'centre_clearances', 'stoppage_clearances', 'score_involvements',
       'metres_gained', 'turnovers', 'intercepts', 'tackles_inside_fifty',
       'contest_def_losses', 'contest_def_one_on_ones',
       'contest_off_one_on_ones', 'contest_off_wins', 'def_half_pressure_acts',
       'effective_kicks', 'f50_ground_ball_gets', 'ground_ball_gets',
       'hitouts_to_advantage', 'hitout_win_percentage', 'intercept_marks',
       'marks_on_lead', 'pressure_acts', 'rating_points',
       'score_launches', 'spoils'
]

# %%
df = df[reorder_cols]

# %%
df.to_parquet('../../data/raw/stats_23.parquet')
